# %% [markdown]
# # Truecar.com webscraping and connecting to PostgreSQL

# %% [markdown]
# ![](https://i.imgur.com/vlMVhCm.jpg)

# %% [markdown]
# ## 1. Introduction :

# %% [markdown]
# ### 1.1. What is web scraping

# %% [markdown]
# Web scraping is the process of collecting structured web data in an automated fashion. Some of the main use cases of web scraping include price monitoring, price intelligence, news monitoring, lead generation, and market research among many others.
#
# In general, web data extraction is used by people and businesses who want to make use of the vast amount of publicly available web data to make smarter decisions.
#
# There are a number of tools and methods for performing web scraping; using network traffic, Scrappy, Selenium and Beautiful Soup are the most popular methods.

# %% [markdown]
# ### 1.2. Tools used in this project

# %% [markdown]
# Most scraping projects use Beautiful Soup but using network traffic can also be used to get the information we need
#
# In this project, we are going to use Python as our coding language to scrape.
#
# In Python, We will mainly use Requests library to get the information from the websites.
#
# Then the information that has been scrapped will be turned into a Pandas DataFrame and then
# we are going to save the file as CSV.

# %% [markdown]
# ## 2. Project Steps:

# %% [markdown]
# #### Part 1 - listings for New York
#
# - Assessing the website to find the information we need
# - Copying as cURL and turning to python
# - Using request to download the information
# - Extracting info for one item
# - Putting it all together and get the information automatically
#
# #### Part 2 - listings for San Francisco
# - Putting it all together and get the information automatically for San Francisco
#
# #### Part 3
# - exporting the 10k results to a PostgreSQL database

# %% [markdown]
# # Part 1 - Truecar.com - New York

# %% [markdown]
# ### assessing the website to find the information we need

# %% [markdown]
# In order to get the information we need we are going to right click and use inspect to go to the source
#
# Under Network tab we can see there is fetch/XHR tab. while we scroll on the page the info gets populated

# %% [markdown]
# ![](https://i.imgur.com/ezL8G0C.jpg)

# %% [markdown]
# we need to check the items under the Name column and find the information we need
#
# This part is a trial and error until we find the part we need

# %% [markdown]
# ![](https://i.imgur.com/jW8orea.jpg)

# %% [markdown]
# ### copying as cURL and turning to python

# %% [markdown]
# After we have found the right object, we should right click on the object and then Copy - Copy as cURL(cmd)
#
# Then we need a cURL converter to turn it into a python format
# we can use curl.trillworks.com
#
# after converting that we will bring the python version to jupyter notebook and continue the project

# %%
#importing neccessary libraries
import requests
import pandas as pd 
from sqlalchemy import create_engine

# %% [markdown]
# ### using request to download the information

# %%
headers = {
    'authority': 'www.truecar.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^92^\\^, ^\\^',
    'accept': 'application/json, text/plain, */*',
    'x-xsrf-token': 'Ur/kxt0PrKLpIlS3QELPXZBZHMSME0gTzs47TPfIUiC1LJqIt9HlLYrLTMgwB5qE6zC2M5Psn5Er+4Qm82MgEA==',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.truecar.com/used-cars-for-sale/listings/location-new-york-ny/',
    'accept-language': 'en-US,en;q=0.9,de-DE;q=0.8,de;q=0.7',
    'cookie': 'tc_v=732d8f6c-016d-4e04-99ea-962821b285bd; u=rBEABWDn9kVuLQARuYhKAg==; user_zip_code_san-francisco-ca=94102; user_zip_code_new-york-ny=10001; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; _abp_auth_s=aLdzR1stp7FxiV6Cbnggg8fmtny6X9FAap2fnCqWeXg; referrer=ZTC0000000; g_state=^{^\\^i_p^\\^:1628151776913,^\\^i_l^\\^:2^}; capselaPreferredPostalCode=10001; XSRF-TOKEN=Ur^%^2Fkxt0PrKLpIlS3QELPXZBZHMSME0gTzs47TPfIUiC1LJqIt9HlLYrLTMgwB5qE6zC2M5Psn5Er^%^2B4Qm82MgEA^%^3D^%^3D; _abp_backend_session=cnN3bFdMQjJQYTlwRFFvS3oybm1oWTl0SVc3NVNGRng5Y01GWHlxa3BybWFJRXM1UkFueTFRWUhMYUtSVW1YZWxNaUFIZ2ZjS2FUQ2pVeURRNG5PeEh6VlRFQjZnRmFLN01PWHZFdjBQTis5UG9VRGFtWko4MFZNY2ZUUGRmS1pkSFdmcnB4TVkwMnJGREZBblZla1RRPT0tLW5BQjFPdHVvTk1VbHJZL3lwQ2MrTUE9PQ^%^3D^%^3D--a4caf99167368bcbbcd454b4ffe52eb35169abe0; _dd_s=rum=0&expire=1628067151364',
    'if-none-match': 'W/^\\^ad5f12263df3f1f7dad67afa854d2880^\\^',
}

params = (
    ('city', 'new-york'),
    ('collapse', 'true'),
    ('fallback', 'true'),
    ('include_incentives', 'true'),
    ('include_targeted_incentives', 'true'),
    ('new_or_used', 'u'),
    ('page', '1'),
    # in the first page these is no page attribute so we scraped the second page and then replace it with number 1
    ('per_page', '30'),
    ('postal_code', '10001'),
    ('search_event', 'true'),
    ('sort^/[^/]', 'best_match'),
    ('sponsored', 'true'),
    ('state', 'ny'),
)

response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings', headers=headers, params=params)

# %%
# checking if the request response was successful
response
# Out:
# <Response [200]>

# %%
# creating a json object from the response we got from page 
json_response =response.json()
json_response
#check a couple of cars to see we have the file
# Out:
# {'listings': [{'vehicle': {'body_style_slug': 'sedan',
#     'body_style': 'Sedan',
#     'drive_train': 'AWD',
#     'engine': '2.0L Inline-4 Gas Turbocharged',
#     'fuel_type': 'Gas',
#     'make_id': 4,
#     'make_slug': 'mercedes-benz',
#     'make': 'Mercedes-Benz',
#     'model_id': 7318,
#     'model_slug': 'c-class',
#     'model': 'C-Class',
#     'mpg_city': 23,
#     'mpg_combined': 26,
#     'mpg_highway': 32,
#     'style_id': 59105,
#     'style_slug': 'c-300-4matic-sedan',
#     'style': 'C 300 4MATIC Sedan',
#     'transmission': 'Automatic',
#     'trim_slug': 'c-300',
#     'trim': 'C 300 4MATIC Sedan',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 395165,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'White',
#     'exterior_color_rgb': 'E3E4E8',
#     'exterior_color': 'Polar White',
#     'exterior_color_id': 887864,
#     'interior_color': 'Black',
#     'interior_color_generic': 'Black',
#     'interior_color_rgb': '1B1C20',
#     'interior_color_id': 887849,
#     'list_price': 31901.0,
#     'member_discount': 500.0,
#     'mileage': 19457,
#     'new_or_used': 'USED',
#     'stock_number': '706156',
#     'vin': '55SWF4KB1JU267888',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 15,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1628432246024,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB1JU267888',
#      'reportPullDateString': '2021-08-08T14:17:26.024+00:00'},
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': 'oem-certified',
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB1JU267888',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/2441/88/78/55SWF4KB1JU267888/KCEQX3OXGH6I2AOFTOH2EUG7FM-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/2441/88/78/55SWF4KB1JU267888/KCEQX3OXGH6I2AOFTOH2EUG7FM-318.jpg']},
#    'dealership': {'id': 2441,
#     'name': 'Mercedes-Benz Manhattan',
#     'links': {'website_link': 'http://www.mb-manhattan.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '770 11th Avenue',
#      'address2': None,
#      'postal_code': '10019',
#      'lat': 40.76813,
#      'lng': -73.99287,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 1.26},
#     'parent_id': None},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-08-08T12:40:00.000+00:00',
#    'images': [{'data': {'width': 1024,
#       'cropAvailable': True,
#       'hash': 'listings/2441/88/78/55SWF4KB1JU267888/KCEQX3OXGH6I2AOFTOH2EUG7FM',
#       'height': 768}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': 'Upfront Price Available',
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your Upfront Price',
#     'show_discount_post_lead': True,
#     'description': 'restricted_state_and_list_prices',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': 'Upfront Price Available'},
#    'pricing': {'list_price': 31901,
#     'member_discount': None,
#     'member_price': 31901,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 31901,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 89,
#     'market_difference': 2428.54,
#     'market_difference_display': 1453,
#     'market_difference_percent': 0.071,
#     'market_difference_percent_display': 4.6,
#     'rating': 'EXCELLENT',
#     'callout': {'label': 'Excellent Price',
#      'quality': 'EXCELLENT',
#      'quality_index': 0},
#     'great': 33986.25,
#     'good': 35359.43,
#     'min': 25747.16,
#     'max': 42911.93,
#     'avg': 34329.54,
#     'exceptional': 32613.06},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': '55SWF4KB1JU267888'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'suv',
#     'body_style': 'SUV',
#     'drive_train': '4WD',
#     'engine': '3.6L V-6 Gas',
#     'fuel_type': 'Gas',
#     'make_id': 34,
#     'make_slug': 'jeep',
#     'make': 'Jeep',
#     'model_id': 7291,
#     'model_slug': 'grand-cherokee',
#     'model': 'Grand Cherokee',
#     'mpg_city': 18,
#     'mpg_combined': 21,
#     'mpg_highway': 25,
#     'style_id': 58559,
#     'style_slug': 'limited-4wd',
#     'style': 'Limited 4WD',
#     'transmission': 'Automatic',
#     'trim_slug': 'limited',
#     'trim': 'Limited 4WD',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 392848,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_member',
#     'exterior_color_generic': 'White',
#     'exterior_color_rgb': 'E5E9E5',
#     'exterior_color': 'Bright White Clearcoat',
#     'exterior_color_id': None,
#     'interior_color': 'Black',
#     'interior_color_generic': 'Black',
#     'interior_color_rgb': None,
#     'interior_color_id': None,
#     'list_price': 30162.0,
#     'member_discount': None,
#     'mileage': 26553,
#     'new_or_used': 'USED',
#     'stock_number': 'LM17895',
#     'vin': '1C4RJFBG4JC399626',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 41,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {'mechanical': [{'description': 'NORMAL DUTY SUSPENSION',
#        'msrp': 0.0,
#        'features': ['(STD)'],
#        'oem_code': 'SDA'},
#       {'description': 'ENGINE: 3.6L V6 24V VVT UPG I W/ESS',
#        'msrp': 0.0,
#        'features': ['(STD)'],
#        'oem_code': 'ERC'},
#       {'description': 'TRANSMISSION: 8-SPEED AUTOMATIC (850RE)',
#        'msrp': 0.0,
#        'features': ['(STD)'],
#        'oem_code': 'DFT'},
#       {'description': '3.45 REAR AXLE RATIO',
#        'msrp': 0.0,
#        'features': ['(STD)'],
#        'oem_code': 'DLK'}],
#      'packages': [{'description': 'QUICK ORDER PACKAGE 2BH',
#        'msrp': 0.0,
#        'features': ['Engine: 3.6L V6 24V VVT UPG I w/ESS',
#         'Transmission: 8-Speed Automatic (850RE)'],
#        'oem_code': '2BH'}],
#      'exterior': [{'description': 'WHEELS: 18" X 8.0" TECH GRAY ALUMINUM',
#        'msrp': 0.0,
#        'features': ['(STD)'],
#        'oem_code': 'WBC'},
#       {'description': 'TIRES: P265/60R18 BSW AS LRR',
#        'msrp': 0.0,
#        'features': ['(STD)'],
#        'oem_code': 'TDC'}],
#      'interior': [{'description': 'BLACK, LEATHER TRIMMED BUCKET SEATS',
#        'msrp': 0.0,
#        'features': None,
#        'oem_code': 'CJX9'},
#       {'description': 'RADIO: UCONNECT 4C NAV W/8.4" DISPLAY',
#        'msrp': 1395.0,
#        'features': ['SiriusXM Traffic Plus',
#         'HD Radio',
#         'For Details Visit DriveUconnect.com',
#         '1-Year SiriusXM Guardian Trial',
#         '5-Year SiriusXM Travel Link Service',
#         'GPS Navigation',
#         '5-Year SiriusXM Traffic Service',
#         'SiriusXM Travel Link',
#         '8.4" Touchscreen Display'],
#        'oem_code': 'UAQ'}],
#      'additional equipment': [{'description': 'GVWR: 6,500 LBS',
#        'msrp': 0.0,
#        'features': ['(STD)'],
#        'oem_code': 'Z6K'},
#       {'description': 'POWER SUNROOF',
#        'msrp': 1195.0,
#        'features': None,
#        'oem_code': 'GWA'},
#       {'description': 'FRONT LICENSE PLATE BRACKET',
#        'msrp': 0.0,
#        'features': None,
#        'oem_code': 'MDA'},
#       {'description': 'BLIND SPOT & CROSS PATH DETECTION',
#        'msrp': 595.0,
#        'features': ['Auto Dim Exterior Passenger Mirror'],
#        'oem_code': 'XAN'}]},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1626269406243,
#      'isFrameDamaged': False,
#      'ownerCount': 2,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=1C4RJFBG4JC399626',
#      'reportPullDateString': '2021-07-14T13:30:06.243+00:00'},
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': None,
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=1C4RJFBG4JC399626',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/5836/26/96/1C4RJFBG4JC399626/UV2CGHMUAM37F76YYISBLARYQE-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/5836/26/96/1C4RJFBG4JC399626/UV2CGHMUAM37F76YYISBLARYQE-318.jpg'],
#     'member_price': 30162.0},
#    'dealership': {'id': 5836,
#     'name': 'Lexus of Manhattan',
#     'links': {'website_link': 'www.lexusofmanhattan.com'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '627 11th Avenue',
#      'address2': None,
#      'postal_code': '10036',
#      'lat': 40.76402,
#      'lng': -73.99644,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 0.96},
#     'parent_id': 19544},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-07-14T12:44:00.000+00:00',
#    'images': [{'data': {'width': 1600,
#       'cropAvailable': True,
#       'hash': 'listings/5836/26/96/1C4RJFBG4JC399626/UV2CGHMUAM37F76YYISBLARYQE',
#       'height': 1200}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': None,
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your <span class="true-price"><strong>TRUE</strong>Price</span>',
#     'show_discount_post_lead': False,
#     'description': 'no_discounts',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': None},
#    'pricing': {'list_price': 30162,
#     'member_discount': None,
#     'member_price': 30162,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 30162,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 48,
#     'market_difference': 947.88,
#     'market_difference_display': 463,
#     'market_difference_percent': 0.03,
#     'market_difference_percent_display': 1.5,
#     'rating': 'GREAT',
#     'callout': {'label': 'Great Price',
#      'quality': 'GREAT',
#      'quality_index': 1},
#     'great': 30798.78,
#     'good': 32043.18,
#     'min': 23332.41,
#     'max': 38887.35,
#     'avg': 31109.88,
#     'exceptional': 29554.39},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': '1C4RJFBG4JC399626'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'suv',
#     'body_style': 'SUV',
#     'drive_train': 'AWD',
#     'engine': '3.5L V-6 Gas',
#     'fuel_type': 'Gas',
#     'make_id': 4,
#     'make_slug': 'mercedes-benz',
#     'make': 'Mercedes-Benz',
#     'model_id': 7369,
#     'model_slug': 'gle',
#     'model': 'GLE',
#     'mpg_city': 18,
#     'mpg_combined': 19,
#     'mpg_highway': 22,
#     'style_id': 59472,
#     'style_slug': 'gle-350-4matic-suv',
#     'style': 'GLE 350 4MATIC SUV',
#     'transmission': 'Automatic',
#     'trim_slug': 'gle-350',
#     'trim': 'GLE 350 4MATIC SUV',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 395342,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'Black',
#     'exterior_color_rgb': '0A0A0B',
#     'exterior_color': 'Black',
#     'exterior_color_id': 892830,
#     'interior_color': 'Black',
#     'interior_color_generic': 'Black',
#     'interior_color_rgb': '1B1C20',
#     'interior_color_id': 892821,
#     'list_price': 39901.0,
#     'member_discount': 500.0,
#     'mileage': 29557,
#     'new_or_used': 'USED',
#     'stock_number': '706010',
#     'vin': '4JGDA5HB0JB170670',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 50,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1624649945634,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 1,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=4JGDA5HB0JB170670',
#      'reportPullDateString': '2021-06-25T19:39:05.634+00:00'},
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': 'oem-certified',
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=4JGDA5HB0JB170670',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/2441/70/06/4JGDA5HB0JB170670/IRD5PZZFDBQ24PTIAHE3OLRR74-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/2441/70/06/4JGDA5HB0JB170670/IRD5PZZFDBQ24PTIAHE3OLRR74-318.jpg']},
#    'dealership': {'id': 2441,
#     'name': 'Mercedes-Benz Manhattan',
#     'links': {'website_link': 'http://www.mb-manhattan.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '770 11th Avenue',
#      'address2': None,
#      'postal_code': '10019',
#      'lat': 40.76813,
#      'lng': -73.99287,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 1.26},
#     'parent_id': None},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-08-19T18:43:00.000+00:00',
#    'images': [{'data': {'width': 640,
#       'cropAvailable': True,
#       'hash': 'listings/2441/70/06/4JGDA5HB0JB170670/IRD5PZZFDBQ24PTIAHE3OLRR74',
#       'height': 480}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': 'Upfront Price Available',
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your Upfront Price',
#     'show_discount_post_lead': True,
#     'description': 'restricted_state_and_list_prices',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': 'Upfront Price Available'},
#    'pricing': {'list_price': 39901,
#     'member_discount': None,
#     'member_price': 39901,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 39901,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 30,
#     'market_difference': 1573.11,
#     'market_difference_display': 836,
#     'market_difference_percent': 0.038,
#     'market_difference_percent_display': 2.1,
#     'rating': 'GREAT',
#     'callout': {'label': 'Great Price',
#      'quality': 'GREAT',
#      'quality_index': 1},
#     'great': 41059.37,
#     'good': 42718.33,
#     'min': 31105.58,
#     'max': 51842.64,
#     'avg': 41474.11,
#     'exceptional': 39400.4},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': '4JGDA5HB0JB170670'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'sedan',
#     'body_style': 'Sedan',
#     'drive_train': 'AWD',
#     'engine': '2.0L Inline-4 Gas Turbocharged',
#     'fuel_type': 'Gas',
#     'make_id': 4,
#     'make_slug': 'mercedes-benz',
#     'make': 'Mercedes-Benz',
#     'model_id': 7318,
#     'model_slug': 'c-class',
#     'model': 'C-Class',
#     'mpg_city': 23,
#     'mpg_combined': 26,
#     'mpg_highway': 32,
#     'style_id': 59105,
#     'style_slug': 'c-300-4matic-sedan',
#     'style': 'C 300 4MATIC Sedan',
#     'transmission': 'Automatic',
#     'trim_slug': 'c-300',
#     'trim': 'C 300 4MATIC Sedan',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 395165,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'Black',
#     'exterior_color_rgb': '0A0A0B',
#     'exterior_color': 'Black',
#     'exterior_color_id': 887865,
#     'interior_color': 'Black',
#     'interior_color_generic': 'Black',
#     'interior_color_rgb': '1B1C20',
#     'interior_color_id': 887854,
#     'list_price': 32901.0,
#     'member_discount': 500.0,
#     'mileage': 17880,
#     'new_or_used': 'USED',
#     'stock_number': '18542',
#     'vin': '55SWF4KB4JU273751',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 30,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1626982711278,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB4JU273751',
#      'reportPullDateString': '2021-07-22T19:38:31.278+00:00'},
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': 'oem-certified',
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB4JU273751',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/2441/51/37/55SWF4KB4JU273751/3JEK3SYJNHXLJ7DJAXA5ESSO54-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/2441/51/37/55SWF4KB4JU273751/3JEK3SYJNHXLJ7DJAXA5ESSO54-318.jpg']},
#    'dealership': {'id': 2441,
#     'name': 'Mercedes-Benz Manhattan',
#     'links': {'website_link': 'http://www.mb-manhattan.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '770 11th Avenue',
#      'address2': None,
#      'postal_code': '10019',
#      'lat': 40.76813,
#      'lng': -73.99287,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 1.26},
#     'parent_id': None},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-07-22T18:40:00.000+00:00',
#    'images': [{'data': {'width': 640,
#       'cropAvailable': True,
#       'hash': 'listings/2441/51/37/55SWF4KB4JU273751/3JEK3SYJNHXLJ7DJAXA5ESSO54',
#       'height': 480}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': 'Upfront Price Available',
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your Upfront Price',
#     'show_discount_post_lead': True,
#     'description': 'restricted_state_and_list_prices',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': 'Upfront Price Available'},
#    'pricing': {'list_price': 32901,
#     'member_discount': None,
#     'member_price': 32901,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 32901,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 56,
#     'market_difference': 923.72,
#     'market_difference_display': 427,
#     'market_difference_percent': 0.027,
#     'market_difference_percent_display': 1.3,
#     'rating': 'GREAT',
#     'callout': {'label': 'Great Price',
#      'quality': 'GREAT',
#      'quality_index': 1},
#     'great': 33486.48,
#     'good': 34839.46,
#     'min': 25368.54,
#     'max': 42280.9,
#     'avg': 33824.72,
#     'exceptional': 32133.49},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': '55SWF4KB4JU273751'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'sedan',
#     'body_style': 'Sedan',
#     'drive_train': 'AWD',
#     'engine': '2.0L Inline-4 Gas Turbocharged',
#     'fuel_type': 'Gas',
#     'make_id': 4,
#     'make_slug': 'mercedes-benz',
#     'make': 'Mercedes-Benz',
#     'model_id': 7318,
#     'model_slug': 'c-class',
#     'model': 'C-Class',
#     'mpg_city': 23,
#     'mpg_combined': 26,
#     'mpg_highway': 32,
#     'style_id': 59105,
#     'style_slug': 'c-300-4matic-sedan',
#     'style': 'C 300 4MATIC Sedan',
#     'transmission': 'Automatic',
#     'trim_slug': 'c-300',
#     'trim': 'C 300 4MATIC Sedan',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 395165,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'Gray',
#     'exterior_color_rgb': '363938',
#     'exterior_color': 'Selenite Grey Metallic',
#     'exterior_color_id': 887872,
#     'interior_color': 'Black',
#     'interior_color_generic': 'Black',
#     'interior_color_rgb': '1B1C20',
#     'interior_color_id': 887849,
#     'list_price': 31901.0,
#     'member_discount': 500.0,
#     'mileage': 26317,
#     'new_or_used': 'USED',
#     'stock_number': '706167',
#     'vin': 'WDDWF4KB6JR313197',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 10,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1628884111285,
#      'isFrameDamaged': False,
#      'ownerCount': 2,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDDWF4KB6JR313197',
#      'reportPullDateString': '2021-08-13T19:48:31.285+00:00'},
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': 'oem-certified',
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDDWF4KB6JR313197',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/2441/97/31/WDDWF4KB6JR313197/5SPO3J7OJXAFYOXQBBW3GLY2PQ-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/2441/97/31/WDDWF4KB6JR313197/5SPO3J7OJXAFYOXQBBW3GLY2PQ-318.jpg']},
#    'dealership': {'id': 2441,
#     'name': 'Mercedes-Benz Manhattan',
#     'links': {'website_link': 'http://www.mb-manhattan.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '770 11th Avenue',
#      'address2': None,
#      'postal_code': '10019',
#      'lat': 40.76813,
#      'lng': -73.99287,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 1.26},
#     'parent_id': None},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-08-13T18:41:00.000+00:00',
#    'images': [{'data': {'width': 1024,
#       'cropAvailable': True,
#       'hash': 'listings/2441/97/31/WDDWF4KB6JR313197/5SPO3J7OJXAFYOXQBBW3GLY2PQ',
#       'height': 768}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': 'Upfront Price Available',
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your Upfront Price',
#     'show_discount_post_lead': True,
#     'description': 'restricted_state_and_list_prices',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': 'Upfront Price Available'},
#    'pricing': {'list_price': 31901,
#     'member_discount': None,
#     'member_price': 31901,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 31901,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 42,
#     'market_difference': 1084.15,
#     'market_difference_display': 547,
#     'market_difference_percent': 0.033,
#     'market_difference_percent_display': 1.7,
#     'rating': 'GREAT',
#     'callout': {'label': 'Great Price',
#      'quality': 'GREAT',
#      'quality_index': 1},
#     'great': 32655.3,
#     'good': 33974.7,
#     'min': 24738.86,
#     'max': 41231.43,
#     'avg': 32985.15,
#     'exceptional': 31335.89},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': 'WDDWF4KB6JR313197'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'suv',
#     'body_style': 'SUV',
#     'drive_train': 'AWD',
#     'engine': '2.5L Inline-4 Gas',
#     'fuel_type': 'Gas',
#     'make_id': 43,
#     'make_slug': 'nissan',
#     'make': 'Nissan',
#     'model_id': 7495,
#     'model_slug': 'rogue',
#     'model': 'Rogue',
#     'mpg_city': 25,
#     'mpg_combined': 27,
#     'mpg_highway': 32,
#     'style_id': 60664,
#     'style_slug': 'sv-awd',
#     'style': 'SV AWD',
#     'transmission': 'Automatic',
#     'trim_slug': 'sv',
#     'trim': 'SV AWD',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 392017,
#     'carfax_report_available': False,
#     'enable_discount': None,
#     'exterior_color_generic': 'Black',
#     'exterior_color_rgb': '1D2020',
#     'exterior_color': 'Magnetic Black',
#     'exterior_color_id': None,
#     'interior_color': 'Charcoal',
#     'interior_color_generic': 'Black',
#     'interior_color_rgb': None,
#     'interior_color_id': None,
#     'list_price': 21303.0,
#     'member_discount': None,
#     'mileage': 24474,
#     'new_or_used': 'USED',
#     'stock_number': '12888UH',
#     'vin': 'KNMAT2MVXJP606606',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 40,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {'interior': [{'description': 'CHARCOAL, CLOTH SEAT TRIM',
#        'msrp': 0.0,
#        'features': None,
#        'oem_code': 'G'}],
#      'additional equipment': [{'description': 'MARCH SOP SPEC',
#        'msrp': 0.0,
#        'features': None,
#        'oem_code': 'MAR'},
#       {'description': 'CHROME REAR BUMPER PROTECTOR',
#        'msrp': 155.0,
#        'features': None,
#        'oem_code': 'BUM'},
#       {'description': 'BLACK SPLASH GUARDS (SET OF 4)',
#        'msrp': 160.0,
#        'features': None,
#        'oem_code': 'SGD'},
#       {'description': 'FLOOR MATS & 2-PC CARGO AREA PROTECTOR',
#        'msrp': 275.0,
#        'features': ['2-pc front and 2-pc 2nd row floor mats', 'First Aid Kit'],
#        'oem_code': 'FL2'}]},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 2,
#      'reportPullDate': 1626401962225,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=KNMAT2MVXJP606606',
#      'reportPullDateString': '2021-07-16T02:19:22.225+00:00'},
#     'multilocation': False,
#     'equipment_rating': 'basicEquipped',
#     'location': 'Long Island City, NY',
#     'price_dropped': False,
#     'certified_pre_owned': None,
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=KNMAT2MVXJP606606',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/270378/06/66/KNMAT2MVXJP606606/D4V2GDXVGEHWCVAQMJ7ZFJGQUU-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/270378/06/66/KNMAT2MVXJP606606/D4V2GDXVGEHWCVAQMJ7ZFJGQUU-318.jpg']},
#    'dealership': {'id': 270378,
#     'name': 'Koeppel Hyundai',
#     'links': {'website_link': 'https://www.koeppelhyundai.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '34-54 44th Street',
#      'address2': None,
#      'postal_code': '11101',
#      'lat': 40.7544,
#      'lng': -73.9183,
#      'city': 'Long Island City',
#      'state': 'NY',
#      'distance': 4.12},
#     'parent_id': None},
#    'payments': {'lease': None,
#     'loan': {'total_monthly_payment': 380.98,
#      'monthly_payment': 346.98,
#      'monthly_tax': 34.0,
#      'total_due_at_signing': 2130.3,
#      'due_at_signing': 2130.3,
#      'taxes_due_at_signing': 0.0,
#      'term': 60,
#      'disclaimer': '$2,130 down payment. 60 monthly payments of $17.96 per $1000 financed at 2.99% APR.'}},
#    'listed_at': '2021-08-10T18:41:00.000+00:00',
#    'images': [{'data': {'width': 640,
#       'cropAvailable': True,
#       'hash': 'listings/270378/06/66/KNMAT2MVXJP606606/D4V2GDXVGEHWCVAQMJ7ZFJGQUU',
#       'height': 480}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': None,
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Dealer Price',
#     'show_discount_post_lead': False,
#     'description': 'no_discounts',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': None},
#    'pricing': {'list_price': 21303,
#     'member_discount': None,
#     'member_price': 21303,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 21303,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 34,
#     'market_difference': 802.4,
#     'market_difference_display': 420,
#     'market_difference_percent': 0.036,
#     'market_difference_percent_display': 2.0,
#     'rating': 'GREAT',
#     'callout': {'label': 'Great Price',
#      'quality': 'GREAT',
#      'quality_index': 1},
#     'great': 21884.35,
#     'good': 22768.56,
#     'min': 16579.05,
#     'max': 27631.75,
#     'avg': 22105.4,
#     'exceptional': 21000.13},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': 'KNMAT2MVXJP606606'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'sedan',
#     'body_style': 'Sedan',
#     'drive_train': 'AWD',
#     'engine': '2.0L Inline-4 Gas Turbocharged',
#     'fuel_type': 'Gas',
#     'make_id': 4,
#     'make_slug': 'mercedes-benz',
#     'make': 'Mercedes-Benz',
#     'model_id': 7341,
#     'model_slug': 'e-class',
#     'model': 'E-Class',
#     'mpg_city': 21,
#     'mpg_combined': 24,
#     'mpg_highway': 29,
#     'style_id': 59447,
#     'style_slug': 'e-300-4matic-sedan',
#     'style': 'E 300 4MATIC Sedan',
#     'transmission': 'Automatic',
#     'trim_slug': 'e-300',
#     'trim': 'E 300 4MATIC Sedan',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 395560,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'Gray',
#     'exterior_color_rgb': '363938',
#     'exterior_color': 'Selenite Grey Metallic',
#     'exterior_color_id': 892378,
#     'interior_color': 'Black',
#     'interior_color_generic': 'Black',
#     'interior_color_rgb': '1B1C20',
#     'interior_color_id': 906671,
#     'list_price': 39901.0,
#     'member_discount': 500.0,
#     'mileage': 38458,
#     'new_or_used': 'USED',
#     'stock_number': '706108',
#     'vin': 'WDDZF4KB0JA346305',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 24,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1627502897134,
#      'isFrameDamaged': False,
#      'ownerCount': 2,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 1,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDDZF4KB0JA346305',
#      'reportPullDateString': '2021-07-28T20:08:17.134+00:00'},
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': 'oem-certified',
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDDZF4KB0JA346305',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/2441/05/63/WDDZF4KB0JA346305/GP6QVQ2X7YJZVBCA2I4I5XF6BY-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/2441/05/63/WDDZF4KB0JA346305/GP6QVQ2X7YJZVBCA2I4I5XF6BY-318.jpg']},
#    'dealership': {'id': 2441,
#     'name': 'Mercedes-Benz Manhattan',
#     'links': {'website_link': 'http://www.mb-manhattan.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '770 11th Avenue',
#      'address2': None,
#      'postal_code': '10019',
#      'lat': 40.76813,
#      'lng': -73.99287,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 1.26},
#     'parent_id': None},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-07-28T18:40:00.000+00:00',
#    'images': [{'data': {'width': 640,
#       'cropAvailable': True,
#       'hash': 'listings/2441/05/63/WDDZF4KB0JA346305/GP6QVQ2X7YJZVBCA2I4I5XF6BY',
#       'height': 480}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': 'Upfront Price Available',
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your Upfront Price',
#     'show_discount_post_lead': True,
#     'description': 'restricted_state_and_list_prices',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': 'Upfront Price Available'},
#    'pricing': {'list_price': 39901,
#     'member_discount': None,
#     'member_price': 39901,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 39901,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 32,
#     'market_difference': 1530.72,
#     'market_difference_display': 806,
#     'market_difference_percent': 0.037,
#     'market_difference_percent_display': 2.0,
#     'rating': 'GREAT',
#     'callout': {'label': 'Great Price',
#      'quality': 'GREAT',
#      'quality_index': 1},
#     'great': 41017.4,
#     'good': 42674.67,
#     'min': 31073.79,
#     'max': 51789.65,
#     'avg': 41431.72,
#     'exceptional': 39360.13},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': 'WDDZF4KB0JA346305'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'suv',
#     'body_style': 'SUV',
#     'drive_train': 'AWD',
#     'engine': '3.5L V-6 Gas',
#     'fuel_type': 'Gas',
#     'make_id': 4,
#     'make_slug': 'mercedes-benz',
#     'make': 'Mercedes-Benz',
#     'model_id': 7369,
#     'model_slug': 'gle',
#     'model': 'GLE',
#     'mpg_city': 18,
#     'mpg_combined': 19,
#     'mpg_highway': 22,
#     'style_id': 59472,
#     'style_slug': 'gle-350-4matic-suv',
#     'style': 'GLE 350 4MATIC SUV',
#     'transmission': 'Automatic',
#     'trim_slug': 'gle-350',
#     'trim': 'GLE 350 4MATIC SUV',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 395342,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'White',
#     'exterior_color_rgb': 'E3E4E8',
#     'exterior_color': 'Polar White',
#     'exterior_color_id': 892831,
#     'interior_color': 'Black',
#     'interior_color_generic': 'Black',
#     'interior_color_rgb': '1B1C20',
#     'interior_color_id': 892821,
#     'list_price': 40901.0,
#     'member_discount': 500.0,
#     'mileage': 36882,
#     'new_or_used': 'USED',
#     'stock_number': '706066',
#     'vin': '4JGDA5HBXJB181305',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 26,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1626637011383,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 1,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=4JGDA5HBXJB181305',
#      'reportPullDateString': '2021-07-18T19:36:51.383+00:00'},
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': 'oem-certified',
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=4JGDA5HBXJB181305',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/2441/05/13/4JGDA5HBXJB181305/75LVV3JIC5XKS27JYSRN6EGUWU-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/2441/05/13/4JGDA5HBXJB181305/75LVV3JIC5XKS27JYSRN6EGUWU-318.jpg']},
#    'dealership': {'id': 2441,
#     'name': 'Mercedes-Benz Manhattan',
#     'links': {'website_link': 'http://www.mb-manhattan.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '770 11th Avenue',
#      'address2': None,
#      'postal_code': '10019',
#      'lat': 40.76813,
#      'lng': -73.99287,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 1.26},
#     'parent_id': None},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-08-21T18:43:00.000+00:00',
#    'images': [{'data': {'width': 1024,
#       'cropAvailable': True,
#       'hash': 'listings/2441/05/13/4JGDA5HBXJB181305/75LVV3JIC5XKS27JYSRN6EGUWU',
#       'height': 768}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': 'Upfront Price Available',
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your Upfront Price',
#     'show_discount_post_lead': True,
#     'description': 'restricted_state_and_list_prices',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': 'Upfront Price Available'},
#    'pricing': {'list_price': 40901,
#     'member_discount': None,
#     'member_price': 40901,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 40901,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 76,
#     'market_difference': 805.57,
#     'market_difference_display': 286,
#     'market_difference_percent': 0.019,
#     'market_difference_percent_display': 0.7,
#     'rating': 'GREAT',
#     'callout': {'label': 'Great Price',
#      'quality': 'GREAT',
#      'quality_index': 1},
#     'great': 41289.5,
#     'good': 42957.76,
#     'min': 31279.92,
#     'max': 52133.21,
#     'avg': 41706.57,
#     'exceptional': 39621.24},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': '4JGDA5HBXJB181305'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'suv',
#     'body_style': 'SUV',
#     'drive_train': 'AWD',
#     'engine': '3.5L V-6 Gas',
#     'fuel_type': 'Gas',
#     'make_id': 4,
#     'make_slug': 'mercedes-benz',
#     'make': 'Mercedes-Benz',
#     'model_id': 7369,
#     'model_slug': 'gle',
#     'model': 'GLE',
#     'mpg_city': 18,
#     'mpg_combined': 19,
#     'mpg_highway': 22,
#     'style_id': 59472,
#     'style_slug': 'gle-350-4matic-suv',
#     'style': 'GLE 350 4MATIC SUV',
#     'transmission': 'Automatic',
#     'trim_slug': 'gle-350',
#     'trim': 'GLE 350 4MATIC SUV',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 395342,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'Black',
#     'exterior_color_rgb': '0A0A0B',
#     'exterior_color': 'Black',
#     'exterior_color_id': 892830,
#     'interior_color': 'Ginger Beige/Black',
#     'interior_color_generic': 'Beige',
#     'interior_color_rgb': 'E8D8BE',
#     'interior_color_id': 892827,
#     'list_price': 39901.0,
#     'member_discount': 500.0,
#     'mileage': 38246,
#     'new_or_used': 'USED',
#     'stock_number': '706017',
#     'vin': '4JGDA5HB5JB123053',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 45,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1624995727059,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 1,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=4JGDA5HB5JB123053',
#      'reportPullDateString': '2021-06-29T19:42:07.059+00:00'},
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': 'oem-certified',
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=4JGDA5HB5JB123053',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/2441/53/30/4JGDA5HB5JB123053/PTVJHQ5ZXMWRABHGO4B4JJTMUY-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/2441/53/30/4JGDA5HB5JB123053/PTVJHQ5ZXMWRABHGO4B4JJTMUY-318.jpg']},
#    'dealership': {'id': 2441,
#     'name': 'Mercedes-Benz Manhattan',
#     'links': {'website_link': 'http://www.mb-manhattan.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '770 11th Avenue',
#      'address2': None,
#      'postal_code': '10019',
#      'lat': 40.76813,
#      'lng': -73.99287,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 1.26},
#     'parent_id': None},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-06-29T18:43:00.000+00:00',
#    'images': [{'data': {'width': 640,
#       'cropAvailable': True,
#       'hash': 'listings/2441/53/30/4JGDA5HB5JB123053/PTVJHQ5ZXMWRABHGO4B4JJTMUY',
#       'height': 480}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': 'Upfront Price Available',
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your Upfront Price',
#     'show_discount_post_lead': True,
#     'description': 'restricted_state_and_list_prices',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': 'Upfront Price Available'},
#    'pricing': {'list_price': 39901,
#     'member_discount': None,
#     'member_price': 39901,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 39901,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 81,
#     'market_difference': 708.48,
#     'market_difference_display': 223,
#     'market_difference_percent': 0.017,
#     'market_difference_percent_display': 0.6,
#     'rating': 'GREAT',
# ...
#        'oem_code': 'PQB'},
#       {'description': 'DRIVER ALERT PACKAGE II',
#        'msrp': 0.0,
#        'features': ['includes (UEU) Forward Collision Alert',
#         '(UHX) Lane Keep Assist/Lane Departure Warning',
#         '(UHY) Low Speed Forward Automatic Braking',
#         '(UKJ) Front Pedestrian Braking',
#         '(TQ5) IntelliBeam headlamps and (UE4) Following Distance Indicator Includes (HS1) Safety Alert Seat.'],
#        'oem_code': 'PDJ'}],
#      'exterior': [{'description': 'WHEELS, 20" X 9" (50.8 CM X 22.9 CM) POLISHED ALUMINUM',
#        'msrp': 0.0,
#        'features': None,
#        'oem_code': 'NZM'},
#       {'description': 'TIRES, 275/60R20SL ALL-TERRAIN, BLACKWALL',
#        'msrp': 0.0,
#        'features': ['(Includes (QAQ) spare tire.)'],
#        'oem_code': 'QAE'}],
#      'interior': [{'description': 'SEATS, FRONT BUCKET',
#        'msrp': 0.0,
#        'features': ['with center console'],
#        'oem_code': 'A50'},
#       {'description': 'DARK WALNUT/SLATE, PERFORATED LEATHER-APPOINTED SEAT TRIM',
#        'msrp': 0.0,
#        'features': None,
#        'oem_code': 'HVE'},
#       {'description': 'AUDIO SYSTEM, PREMIUM GMC INFOTAINMENT SYSTEM WITH NAVIGATION AND 8" DIAGONAL COLOR TOUCH-SCREEN, INCLUDES MULTI-TOUCH DISPLAY, AM/FM STEREO',
#        'msrp': 0.0,
#        'features': ['Bluetooth streaming audio for music and most phones; featuring Android Auto and Apple CarPlay capability for compatible phones',
#         'advanced voice recognition',
#         'in-vehicle apps',
#         'personalized profiles for infotainment and vehicle settings. Includes greater memory'],
#        'oem_code': 'IOT'}]},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1628042881289,
#      'isFrameDamaged': False,
#      'ownerCount': 2,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=1GTU9DED6KZ103822',
#      'reportPullDateString': '2021-08-04T02:08:01.289+00:00'},
#     'multilocation': True,
#     'equipment_rating': 'wellEquipped',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': None,
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=1GTU9DED6KZ103822',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/214232/22/38/1GTU9DED6KZ103822/DIEN3E6ZANK6T6ZLG7WAUUKWB4-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/214232/22/38/1GTU9DED6KZ103822/DIEN3E6ZANK6T6ZLG7WAUUKWB4-318.jpg']},
#    'dealership': {'id': 214232,
#     'name': 'Vroom',
#     'links': {'website_link': 'https://www.vroom.com/?utm_source=truecar&utm_campaign=national4&utm_medium=listings'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': True},
#     'location': {'address1': '12053 Southwest Freeway (Highway 59)',
#      'address2': None,
#      'postal_code': '10013',
#      'lat': 40.7201984374718,
#      'lng': -74.0049785287648,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 2.11},
#     'parent_id': 102176},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-08-04T00:57:00.000+00:00',
#    'images': [{'data': {'width': 1400,
#       'cropAvailable': False,
#       'hash': 'listings/214232/22/38/1GTU9DED6KZ103822/DIEN3E6ZANK6T6ZLG7WAUUKWB4',
#       'height': 788}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': None,
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Dealer Price',
#     'show_discount_post_lead': False,
#     'description': 'no_discounts',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': None},
#    'pricing': {'list_price': 49499,
#     'member_discount': None,
#     'member_price': 49499,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 49499,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 12,
#     'market_difference': 2322.8,
#     'market_difference_display': 1293,
#     'market_difference_percent': 0.045,
#     'market_difference_percent_display': 2.6,
#     'rating': 'GREAT',
#     'callout': {'label': 'Great Price',
#      'quality': 'GREAT',
#      'quality_index': 1},
#     'great': 51303.58,
#     'good': 53376.45,
#     'min': 38866.35,
#     'max': 64777.25,
#     'avg': 51821.8,
#     'exceptional': 49230.71},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'sedan',
#     'body_style': 'Sedan',
#     'drive_train': 'AWD',
#     'engine': '2.0L Inline-4 Gas Turbocharged',
#     'fuel_type': 'Gas',
#     'make_id': 4,
#     'make_slug': 'mercedes-benz',
#     'make': 'Mercedes-Benz',
#     'model_id': 7318,
#     'model_slug': 'c-class',
#     'model': 'C-Class',
#     'mpg_city': 23,
#     'mpg_combined': 26,
#     'mpg_highway': 32,
#     'style_id': 59105,
#     'style_slug': 'c-300-4matic-sedan',
#     'style': 'C 300 4MATIC Sedan',
#     'transmission': 'Automatic',
#     'trim_slug': 'c-300',
#     'trim': 'C 300 4MATIC Sedan',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 395165,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'White',
#     'exterior_color_rgb': 'EEEAD9',
#     'exterior_color': 'Designo Diamond White Metallic',
#     'exterior_color_id': 887877,
#     'interior_color': 'Silk Beige/Black',
#     'interior_color_generic': 'Beige',
#     'interior_color_rgb': 'E8D8BE',
#     'interior_color_id': 887855,
#     'list_price': 32901.0,
#     'member_discount': 0.0,
#     'mileage': 27802,
#     'new_or_used': 'USED',
#     'stock_number': 'SA1014B',
#     'vin': '55SWF4KBXJU274757',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 80,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1623375687859,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KBXJU274757',
#      'reportPullDateString': '2021-06-11T01:41:27.859+00:00'},
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'Stroudsburg, PA',
#     'price_dropped': False,
#     'certified_pre_owned': None,
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KBXJU274757',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/36667/57/47/55SWF4KBXJU274757/2XU5WJXXDC6RLFNIVUIQDTAKNM-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/36667/57/47/55SWF4KBXJU274757/2XU5WJXXDC6RLFNIVUIQDTAKNM-318.jpg']},
#    'dealership': {'id': 36667,
#     'name': 'Ertle Subaru',
#     'links': {'website_link': 'http://www.ertlecars.com/'},
#     'services': {'remote_purchasing': True,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '798 N 9th Street',
#      'address2': None,
#      'postal_code': '18360',
#      'lat': 40.98853,
#      'lng': -75.20937,
#      'city': 'Stroudsburg',
#      'state': 'PA',
#      'distance': 65.46},
#     'parent_id': None},
#    'payments': {'lease': None,
#     'loan': {'total_monthly_payment': 2685.88,
#      'monthly_payment': 2518.64,
#      'monthly_tax': 167.24,
#      'total_due_at_signing': 3290.1,
#      'due_at_signing': 3290.1,
#      'taxes_due_at_signing': 0.0,
#      'term': 60,
#      'disclaimer': '$3,290 down payment. 60 monthly payments of $84.02 per $1000 financed at 100% APR.'}},
#    'listed_at': '2021-06-11T00:43:00.000+00:00',
#    'images': [{'data': {'width': 1536,
#       'cropAvailable': True,
#       'hash': 'listings/36667/57/47/55SWF4KBXJU274757/2XU5WJXXDC6RLFNIVUIQDTAKNM',
#       'height': 1024}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': True,
#     'discount_message_pre_lead': None,
#     'show_list_price_post_lead': False,
#     'cert_title': 'Certificate',
#     'member_price_label_post_lead': 'Dealer Price',
#     'show_discount_post_lead': False,
#     'description': 'non_restricted_state',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': None},
#    'pricing': {'list_price': 32901,
#     'member_discount': None,
#     'member_price': 32901,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 32901,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 7,
#     'market_difference': -72.25,
#     'market_difference_display': 0,
#     'market_difference_percent': -0.002,
#     'market_difference_percent_display': 0.0,
#     'rating': 'FAIR',
#     'callout': {'label': 'Fair Price', 'quality': 'FAIR', 'quality_index': 2},
#     'great': 32500.46,
#     'good': 33813.61,
#     'min': 24621.56,
#     'max': 41035.94,
#     'avg': 32828.75,
#     'exceptional': 31187.31},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'suv',
#     'body_style': 'SUV',
#     'drive_train': 'AWD',
#     'engine': '3.5L V-6 Gas',
#     'fuel_type': 'Gas',
#     'make_id': 22,
#     'make_slug': 'acura',
#     'make': 'Acura',
#     'model_id': 7447,
#     'model_slug': 'mdx',
#     'model': 'MDX',
#     'mpg_city': 18,
#     'mpg_combined': 21,
#     'mpg_highway': 26,
#     'style_id': 60235,
#     'style_slug': 'sh-awd',
#     'style': 'SH-AWD',
#     'transmission': 'Automatic',
#     'trim_slug': 'standard',
#     'trim': 'SH-AWD',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 397045,
#     'carfax_report_available': False,
#     'enable_discount': 'no',
#     'exterior_color_generic': 'Black',
#     'exterior_color_rgb': '1D1D1D',
#     'exterior_color': 'Crystal Black Pearl',
#     'exterior_color_id': 908624,
#     'interior_color': 'Black',
#     'interior_color_generic': 'Black',
#     'interior_color_rgb': None,
#     'interior_color_id': None,
#     'list_price': 32990.0,
#     'member_discount': 0.0,
#     'mileage': 39520,
#     'new_or_used': 'USED',
#     'stock_number': '2001040757',
#     'vin': '5J8YD4H30JL013359',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 3,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1628171405369,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': True,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=5J8YD4H30JL013359',
#      'reportPullDateString': '2021-08-05T13:50:05.369+00:00'},
#     'multilocation': True,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': None,
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=5J8YD4H30JL013359',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/175576/59/33/5J8YD4H30JL013359/7HAZMCXQIORNJMXB3LOCNTEQRA-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/175576/59/33/5J8YD4H30JL013359/7HAZMCXQIORNJMXB3LOCNTEQRA-318.jpg']},
#    'dealership': {'id': 175576,
#     'name': 'Carvana.com',
#     'links': {'website_link': 'http://www.carvana.com?utm_source=Truecar&utm_medium=medium&utm_content=listings&utm_campaign=Truecarlistings'},
#     'services': {'remote_purchasing': True,
#      'nationwide_delivery_provided': True},
#     'location': {'address1': '1123 Cantrell Sansom Road',
#      'address2': None,
#      'postal_code': '10007',
#      'lat': 40.7135457082325,
#      'lng': -74.0085248984158,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 2.6},
#     'parent_id': 102175},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-08-18T12:43:00.000+00:00',
#    'images': [{'data': {'width': 1920,
#       'cropAvailable': False,
#       'hash': 'listings/175576/59/33/5J8YD4H30JL013359/7HAZMCXQIORNJMXB3LOCNTEQRA',
#       'height': 1080}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': None,
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Dealer Price',
#     'show_discount_post_lead': False,
#     'description': 'no_discounts',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': None},
#    'pricing': {'list_price': 32990,
#     'member_discount': None,
#     'member_price': 32990,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 32990,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 95,
#     'market_difference': 398.89,
#     'market_difference_display': 48,
#     'market_difference_percent': 0.012,
#     'market_difference_percent_display': 0.1,
#     'rating': 'GREAT',
#     'callout': {'label': 'Great Price',
#      'quality': 'GREAT',
#      'quality_index': 1},
#     'great': 33055.0,
#     'good': 34390.55,
#     'min': 25041.66,
#     'max': 41736.11,
#     'avg': 33388.89,
#     'exceptional': 31719.44},
#    'prospected': False,
#    'prospected_at': None}],
#  'location': {'id': 3548,
#   'postal_code': '10001',
#   'postal_code_name': None,
#   'city': 'New York',
#   'area_code': '646',
#   'county': 'New York',
#   'timezone': 'Eastern Time (US & Canada)',
#   'daylight_savings_time': True,
#   'fips': '36061',
#   'slug': 'new-york-ny',
#   'seo_city': True,
#   'primary': True,
#   'created_at': '2018-04-24T20:04:13.622Z',
#   'updated_at': '2021-08-02T06:14:01.764Z',
#   'center': [40.750160565587606, -73.9967771003169],
#   'state_id': 38,
#   'geo_centroid': 'POINT (-73.9967771003169 40.750160565587606)',
#   'deleted_at': None,
#   'population': 21102,
#   'household_count': 11031,
#   'average_house_value': 386800,
#   'income_per_household': 92840,
#   'state': 'NY'}}

# %%
# check what type of object is our json

type(json_response)
# Out:
# dict

# %%
json_response.keys()
# Out:
# dict_keys(['listings', 'page', 'per_page', 'total', 'fallback', 'fallback_step', 'refine_parameters', 'display', 'list_price', 'sponsored_listings', 'location'])

# %% [markdown]
# the same number of keys as the ones in the network header in page
#
# the info we need as shown on the page is in "listings" key values

# %% [markdown]
# ### extracting info for one item

# %%
# the information we are going to get from the json is :
# brand
# model
# mileage
#year
# price

# %%
results_json =json_response["listings"]
results_json
# Out:
# [{'vehicle': {'body_style_slug': 'sedan',
#    'body_style': 'Sedan',
#    'drive_train': 'AWD',
#    'engine': '2.0L Inline-4 Gas Turbocharged',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 7318,
#    'model_slug': 'c-class',
#    'model': 'C-Class',
#    'mpg_city': 23,
#    'mpg_combined': 26,
#    'mpg_highway': 32,
#    'style_id': 59105,
#    'style_slug': 'c-300-4matic-sedan',
#    'style': 'C 300 4MATIC Sedan',
#    'transmission': 'Automatic',
#    'trim_slug': 'c-300',
#    'trim': 'C 300 4MATIC Sedan',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 395165,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'White',
#    'exterior_color_rgb': 'E3E4E8',
#    'exterior_color': 'Polar White',
#    'exterior_color_id': 887864,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': '1B1C20',
#    'interior_color_id': 887849,
#    'list_price': 31901.0,
#    'member_discount': 500.0,
#    'mileage': 19457,
#    'new_or_used': 'USED',
#    'stock_number': '706156',
#    'vin': '55SWF4KB1JU267888',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 15,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1628432246024,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB1JU267888',
#     'reportPullDateString': '2021-08-08T14:17:26.024+00:00'},
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB1JU267888',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/2441/88/78/55SWF4KB1JU267888/KCEQX3OXGH6I2AOFTOH2EUG7FM-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/2441/88/78/55SWF4KB1JU267888/KCEQX3OXGH6I2AOFTOH2EUG7FM-318.jpg']},
#   'dealership': {'id': 2441,
#    'name': 'Mercedes-Benz Manhattan',
#    'links': {'website_link': 'http://www.mb-manhattan.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '770 11th Avenue',
#     'address2': None,
#     'postal_code': '10019',
#     'lat': 40.76813,
#     'lng': -73.99287,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 1.26},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-08-08T12:40:00.000+00:00',
#   'images': [{'data': {'width': 1024,
#      'cropAvailable': True,
#      'hash': 'listings/2441/88/78/55SWF4KB1JU267888/KCEQX3OXGH6I2AOFTOH2EUG7FM',
#      'height': 768}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': 'Upfront Price Available',
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your Upfront Price',
#    'show_discount_post_lead': True,
#    'description': 'restricted_state_and_list_prices',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Upfront Price Available'},
#   'pricing': {'list_price': 31901,
#    'member_discount': None,
#    'member_price': 31901,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 31901,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 89,
#    'market_difference': 2428.54,
#    'market_difference_display': 1453,
#    'market_difference_percent': 0.071,
#    'market_difference_percent_display': 4.6,
#    'rating': 'EXCELLENT',
#    'callout': {'label': 'Excellent Price',
#     'quality': 'EXCELLENT',
#     'quality_index': 0},
#    'great': 33986.25,
#    'good': 35359.43,
#    'min': 25747.16,
#    'max': 42911.93,
#    'avg': 34329.54,
#    'exceptional': 32613.06},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '55SWF4KB1JU267888'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'suv',
#    'body_style': 'SUV',
#    'drive_train': '4WD',
#    'engine': '3.6L V-6 Gas',
#    'fuel_type': 'Gas',
#    'make_id': 34,
#    'make_slug': 'jeep',
#    'make': 'Jeep',
#    'model_id': 7291,
#    'model_slug': 'grand-cherokee',
#    'model': 'Grand Cherokee',
#    'mpg_city': 18,
#    'mpg_combined': 21,
#    'mpg_highway': 25,
#    'style_id': 58559,
#    'style_slug': 'limited-4wd',
#    'style': 'Limited 4WD',
#    'transmission': 'Automatic',
#    'trim_slug': 'limited',
#    'trim': 'Limited 4WD',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 392848,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_member',
#    'exterior_color_generic': 'White',
#    'exterior_color_rgb': 'E5E9E5',
#    'exterior_color': 'Bright White Clearcoat',
#    'exterior_color_id': None,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': None,
#    'interior_color_id': None,
#    'list_price': 30162.0,
#    'member_discount': None,
#    'mileage': 26553,
#    'new_or_used': 'USED',
#    'stock_number': 'LM17895',
#    'vin': '1C4RJFBG4JC399626',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 41,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {'mechanical': [{'description': 'NORMAL DUTY SUSPENSION',
#       'msrp': 0.0,
#       'features': ['(STD)'],
#       'oem_code': 'SDA'},
#      {'description': 'ENGINE: 3.6L V6 24V VVT UPG I W/ESS',
#       'msrp': 0.0,
#       'features': ['(STD)'],
#       'oem_code': 'ERC'},
#      {'description': 'TRANSMISSION: 8-SPEED AUTOMATIC (850RE)',
#       'msrp': 0.0,
#       'features': ['(STD)'],
#       'oem_code': 'DFT'},
#      {'description': '3.45 REAR AXLE RATIO',
#       'msrp': 0.0,
#       'features': ['(STD)'],
#       'oem_code': 'DLK'}],
#     'packages': [{'description': 'QUICK ORDER PACKAGE 2BH',
#       'msrp': 0.0,
#       'features': ['Engine: 3.6L V6 24V VVT UPG I w/ESS',
#        'Transmission: 8-Speed Automatic (850RE)'],
#       'oem_code': '2BH'}],
#     'exterior': [{'description': 'WHEELS: 18" X 8.0" TECH GRAY ALUMINUM',
#       'msrp': 0.0,
#       'features': ['(STD)'],
#       'oem_code': 'WBC'},
#      {'description': 'TIRES: P265/60R18 BSW AS LRR',
#       'msrp': 0.0,
#       'features': ['(STD)'],
#       'oem_code': 'TDC'}],
#     'interior': [{'description': 'BLACK, LEATHER TRIMMED BUCKET SEATS',
#       'msrp': 0.0,
#       'features': None,
#       'oem_code': 'CJX9'},
#      {'description': 'RADIO: UCONNECT 4C NAV W/8.4" DISPLAY',
#       'msrp': 1395.0,
#       'features': ['SiriusXM Traffic Plus',
#        'HD Radio',
#        'For Details Visit DriveUconnect.com',
#        '1-Year SiriusXM Guardian Trial',
#        '5-Year SiriusXM Travel Link Service',
#        'GPS Navigation',
#        '5-Year SiriusXM Traffic Service',
#        'SiriusXM Travel Link',
#        '8.4" Touchscreen Display'],
#       'oem_code': 'UAQ'}],
#     'additional equipment': [{'description': 'GVWR: 6,500 LBS',
#       'msrp': 0.0,
#       'features': ['(STD)'],
#       'oem_code': 'Z6K'},
#      {'description': 'POWER SUNROOF',
#       'msrp': 1195.0,
#       'features': None,
#       'oem_code': 'GWA'},
#      {'description': 'FRONT LICENSE PLATE BRACKET',
#       'msrp': 0.0,
#       'features': None,
#       'oem_code': 'MDA'},
#      {'description': 'BLIND SPOT & CROSS PATH DETECTION',
#       'msrp': 595.0,
#       'features': ['Auto Dim Exterior Passenger Mirror'],
#       'oem_code': 'XAN'}]},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1626269406243,
#     'isFrameDamaged': False,
#     'ownerCount': 2,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=1C4RJFBG4JC399626',
#     'reportPullDateString': '2021-07-14T13:30:06.243+00:00'},
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': None,
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=1C4RJFBG4JC399626',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/5836/26/96/1C4RJFBG4JC399626/UV2CGHMUAM37F76YYISBLARYQE-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/5836/26/96/1C4RJFBG4JC399626/UV2CGHMUAM37F76YYISBLARYQE-318.jpg'],
#    'member_price': 30162.0},
#   'dealership': {'id': 5836,
#    'name': 'Lexus of Manhattan',
#    'links': {'website_link': 'www.lexusofmanhattan.com'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '627 11th Avenue',
#     'address2': None,
#     'postal_code': '10036',
#     'lat': 40.76402,
#     'lng': -73.99644,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 0.96},
#    'parent_id': 19544},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-07-14T12:44:00.000+00:00',
#   'images': [{'data': {'width': 1600,
#      'cropAvailable': True,
#      'hash': 'listings/5836/26/96/1C4RJFBG4JC399626/UV2CGHMUAM37F76YYISBLARYQE',
#      'height': 1200}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': None,
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your <span class="true-price"><strong>TRUE</strong>Price</span>',
#    'show_discount_post_lead': False,
#    'description': 'no_discounts',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': None},
#   'pricing': {'list_price': 30162,
#    'member_discount': None,
#    'member_price': 30162,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 30162,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 48,
#    'market_difference': 947.88,
#    'market_difference_display': 463,
#    'market_difference_percent': 0.03,
#    'market_difference_percent_display': 1.5,
#    'rating': 'GREAT',
#    'callout': {'label': 'Great Price', 'quality': 'GREAT', 'quality_index': 1},
#    'great': 30798.78,
#    'good': 32043.18,
#    'min': 23332.41,
#    'max': 38887.35,
#    'avg': 31109.88,
#    'exceptional': 29554.39},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '1C4RJFBG4JC399626'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'suv',
#    'body_style': 'SUV',
#    'drive_train': 'AWD',
#    'engine': '3.5L V-6 Gas',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 7369,
#    'model_slug': 'gle',
#    'model': 'GLE',
#    'mpg_city': 18,
#    'mpg_combined': 19,
#    'mpg_highway': 22,
#    'style_id': 59472,
#    'style_slug': 'gle-350-4matic-suv',
#    'style': 'GLE 350 4MATIC SUV',
#    'transmission': 'Automatic',
#    'trim_slug': 'gle-350',
#    'trim': 'GLE 350 4MATIC SUV',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 395342,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'Black',
#    'exterior_color_rgb': '0A0A0B',
#    'exterior_color': 'Black',
#    'exterior_color_id': 892830,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': '1B1C20',
#    'interior_color_id': 892821,
#    'list_price': 39901.0,
#    'member_discount': 500.0,
#    'mileage': 29557,
#    'new_or_used': 'USED',
#    'stock_number': '706010',
#    'vin': '4JGDA5HB0JB170670',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 50,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1624649945634,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 1,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=4JGDA5HB0JB170670',
#     'reportPullDateString': '2021-06-25T19:39:05.634+00:00'},
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=4JGDA5HB0JB170670',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/2441/70/06/4JGDA5HB0JB170670/IRD5PZZFDBQ24PTIAHE3OLRR74-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/2441/70/06/4JGDA5HB0JB170670/IRD5PZZFDBQ24PTIAHE3OLRR74-318.jpg']},
#   'dealership': {'id': 2441,
#    'name': 'Mercedes-Benz Manhattan',
#    'links': {'website_link': 'http://www.mb-manhattan.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '770 11th Avenue',
#     'address2': None,
#     'postal_code': '10019',
#     'lat': 40.76813,
#     'lng': -73.99287,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 1.26},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-08-19T18:43:00.000+00:00',
#   'images': [{'data': {'width': 640,
#      'cropAvailable': True,
#      'hash': 'listings/2441/70/06/4JGDA5HB0JB170670/IRD5PZZFDBQ24PTIAHE3OLRR74',
#      'height': 480}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': 'Upfront Price Available',
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your Upfront Price',
#    'show_discount_post_lead': True,
#    'description': 'restricted_state_and_list_prices',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Upfront Price Available'},
#   'pricing': {'list_price': 39901,
#    'member_discount': None,
#    'member_price': 39901,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 39901,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 30,
#    'market_difference': 1573.11,
#    'market_difference_display': 836,
#    'market_difference_percent': 0.038,
#    'market_difference_percent_display': 2.1,
#    'rating': 'GREAT',
#    'callout': {'label': 'Great Price', 'quality': 'GREAT', 'quality_index': 1},
#    'great': 41059.37,
#    'good': 42718.33,
#    'min': 31105.58,
#    'max': 51842.64,
#    'avg': 41474.11,
#    'exceptional': 39400.4},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '4JGDA5HB0JB170670'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'sedan',
#    'body_style': 'Sedan',
#    'drive_train': 'AWD',
#    'engine': '2.0L Inline-4 Gas Turbocharged',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 7318,
#    'model_slug': 'c-class',
#    'model': 'C-Class',
#    'mpg_city': 23,
#    'mpg_combined': 26,
#    'mpg_highway': 32,
#    'style_id': 59105,
#    'style_slug': 'c-300-4matic-sedan',
#    'style': 'C 300 4MATIC Sedan',
#    'transmission': 'Automatic',
#    'trim_slug': 'c-300',
#    'trim': 'C 300 4MATIC Sedan',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 395165,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'Black',
#    'exterior_color_rgb': '0A0A0B',
#    'exterior_color': 'Black',
#    'exterior_color_id': 887865,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': '1B1C20',
#    'interior_color_id': 887854,
#    'list_price': 32901.0,
#    'member_discount': 500.0,
#    'mileage': 17880,
#    'new_or_used': 'USED',
#    'stock_number': '18542',
#    'vin': '55SWF4KB4JU273751',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 30,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1626982711278,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB4JU273751',
#     'reportPullDateString': '2021-07-22T19:38:31.278+00:00'},
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB4JU273751',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/2441/51/37/55SWF4KB4JU273751/3JEK3SYJNHXLJ7DJAXA5ESSO54-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/2441/51/37/55SWF4KB4JU273751/3JEK3SYJNHXLJ7DJAXA5ESSO54-318.jpg']},
#   'dealership': {'id': 2441,
#    'name': 'Mercedes-Benz Manhattan',
#    'links': {'website_link': 'http://www.mb-manhattan.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '770 11th Avenue',
#     'address2': None,
#     'postal_code': '10019',
#     'lat': 40.76813,
#     'lng': -73.99287,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 1.26},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-07-22T18:40:00.000+00:00',
#   'images': [{'data': {'width': 640,
#      'cropAvailable': True,
#      'hash': 'listings/2441/51/37/55SWF4KB4JU273751/3JEK3SYJNHXLJ7DJAXA5ESSO54',
#      'height': 480}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': 'Upfront Price Available',
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your Upfront Price',
#    'show_discount_post_lead': True,
#    'description': 'restricted_state_and_list_prices',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Upfront Price Available'},
#   'pricing': {'list_price': 32901,
#    'member_discount': None,
#    'member_price': 32901,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 32901,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 56,
#    'market_difference': 923.72,
#    'market_difference_display': 427,
#    'market_difference_percent': 0.027,
#    'market_difference_percent_display': 1.3,
#    'rating': 'GREAT',
#    'callout': {'label': 'Great Price', 'quality': 'GREAT', 'quality_index': 1},
#    'great': 33486.48,
#    'good': 34839.46,
#    'min': 25368.54,
#    'max': 42280.9,
#    'avg': 33824.72,
#    'exceptional': 32133.49},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '55SWF4KB4JU273751'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'sedan',
#    'body_style': 'Sedan',
#    'drive_train': 'AWD',
#    'engine': '2.0L Inline-4 Gas Turbocharged',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 7318,
#    'model_slug': 'c-class',
#    'model': 'C-Class',
#    'mpg_city': 23,
#    'mpg_combined': 26,
#    'mpg_highway': 32,
#    'style_id': 59105,
#    'style_slug': 'c-300-4matic-sedan',
#    'style': 'C 300 4MATIC Sedan',
#    'transmission': 'Automatic',
#    'trim_slug': 'c-300',
#    'trim': 'C 300 4MATIC Sedan',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 395165,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'Gray',
#    'exterior_color_rgb': '363938',
#    'exterior_color': 'Selenite Grey Metallic',
#    'exterior_color_id': 887872,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': '1B1C20',
#    'interior_color_id': 887849,
#    'list_price': 31901.0,
#    'member_discount': 500.0,
#    'mileage': 26317,
#    'new_or_used': 'USED',
#    'stock_number': '706167',
#    'vin': 'WDDWF4KB6JR313197',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 10,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1628884111285,
#     'isFrameDamaged': False,
#     'ownerCount': 2,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDDWF4KB6JR313197',
#     'reportPullDateString': '2021-08-13T19:48:31.285+00:00'},
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDDWF4KB6JR313197',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/2441/97/31/WDDWF4KB6JR313197/5SPO3J7OJXAFYOXQBBW3GLY2PQ-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/2441/97/31/WDDWF4KB6JR313197/5SPO3J7OJXAFYOXQBBW3GLY2PQ-318.jpg']},
#   'dealership': {'id': 2441,
#    'name': 'Mercedes-Benz Manhattan',
#    'links': {'website_link': 'http://www.mb-manhattan.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '770 11th Avenue',
#     'address2': None,
#     'postal_code': '10019',
#     'lat': 40.76813,
#     'lng': -73.99287,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 1.26},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-08-13T18:41:00.000+00:00',
#   'images': [{'data': {'width': 1024,
#      'cropAvailable': True,
#      'hash': 'listings/2441/97/31/WDDWF4KB6JR313197/5SPO3J7OJXAFYOXQBBW3GLY2PQ',
#      'height': 768}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': 'Upfront Price Available',
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your Upfront Price',
#    'show_discount_post_lead': True,
#    'description': 'restricted_state_and_list_prices',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Upfront Price Available'},
#   'pricing': {'list_price': 31901,
#    'member_discount': None,
#    'member_price': 31901,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 31901,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 42,
#    'market_difference': 1084.15,
#    'market_difference_display': 547,
#    'market_difference_percent': 0.033,
#    'market_difference_percent_display': 1.7,
#    'rating': 'GREAT',
#    'callout': {'label': 'Great Price', 'quality': 'GREAT', 'quality_index': 1},
#    'great': 32655.3,
#    'good': 33974.7,
#    'min': 24738.86,
#    'max': 41231.43,
#    'avg': 32985.15,
#    'exceptional': 31335.89},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': 'WDDWF4KB6JR313197'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'suv',
#    'body_style': 'SUV',
#    'drive_train': 'AWD',
#    'engine': '2.5L Inline-4 Gas',
#    'fuel_type': 'Gas',
#    'make_id': 43,
#    'make_slug': 'nissan',
#    'make': 'Nissan',
#    'model_id': 7495,
#    'model_slug': 'rogue',
#    'model': 'Rogue',
#    'mpg_city': 25,
#    'mpg_combined': 27,
#    'mpg_highway': 32,
#    'style_id': 60664,
#    'style_slug': 'sv-awd',
#    'style': 'SV AWD',
#    'transmission': 'Automatic',
#    'trim_slug': 'sv',
#    'trim': 'SV AWD',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 392017,
#    'carfax_report_available': False,
#    'enable_discount': None,
#    'exterior_color_generic': 'Black',
#    'exterior_color_rgb': '1D2020',
#    'exterior_color': 'Magnetic Black',
#    'exterior_color_id': None,
#    'interior_color': 'Charcoal',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': None,
#    'interior_color_id': None,
#    'list_price': 21303.0,
#    'member_discount': None,
#    'mileage': 24474,
#    'new_or_used': 'USED',
#    'stock_number': '12888UH',
#    'vin': 'KNMAT2MVXJP606606',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 40,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {'interior': [{'description': 'CHARCOAL, CLOTH SEAT TRIM',
#       'msrp': 0.0,
#       'features': None,
#       'oem_code': 'G'}],
#     'additional equipment': [{'description': 'MARCH SOP SPEC',
#       'msrp': 0.0,
#       'features': None,
#       'oem_code': 'MAR'},
#      {'description': 'CHROME REAR BUMPER PROTECTOR',
#       'msrp': 155.0,
#       'features': None,
#       'oem_code': 'BUM'},
#      {'description': 'BLACK SPLASH GUARDS (SET OF 4)',
#       'msrp': 160.0,
#       'features': None,
#       'oem_code': 'SGD'},
#      {'description': 'FLOOR MATS & 2-PC CARGO AREA PROTECTOR',
#       'msrp': 275.0,
#       'features': ['2-pc front and 2-pc 2nd row floor mats', 'First Aid Kit'],
#       'oem_code': 'FL2'}]},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 2,
#     'reportPullDate': 1626401962225,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=KNMAT2MVXJP606606',
#     'reportPullDateString': '2021-07-16T02:19:22.225+00:00'},
#    'multilocation': False,
#    'equipment_rating': 'basicEquipped',
#    'location': 'Long Island City, NY',
#    'price_dropped': False,
#    'certified_pre_owned': None,
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=KNMAT2MVXJP606606',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/270378/06/66/KNMAT2MVXJP606606/D4V2GDXVGEHWCVAQMJ7ZFJGQUU-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/270378/06/66/KNMAT2MVXJP606606/D4V2GDXVGEHWCVAQMJ7ZFJGQUU-318.jpg']},
#   'dealership': {'id': 270378,
#    'name': 'Koeppel Hyundai',
#    'links': {'website_link': 'https://www.koeppelhyundai.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '34-54 44th Street',
#     'address2': None,
#     'postal_code': '11101',
#     'lat': 40.7544,
#     'lng': -73.9183,
#     'city': 'Long Island City',
#     'state': 'NY',
#     'distance': 4.12},
#    'parent_id': None},
#   'payments': {'lease': None,
#    'loan': {'total_monthly_payment': 380.98,
#     'monthly_payment': 346.98,
#     'monthly_tax': 34.0,
#     'total_due_at_signing': 2130.3,
#     'due_at_signing': 2130.3,
#     'taxes_due_at_signing': 0.0,
#     'term': 60,
#     'disclaimer': '$2,130 down payment. 60 monthly payments of $17.96 per $1000 financed at 2.99% APR.'}},
#   'listed_at': '2021-08-10T18:41:00.000+00:00',
#   'images': [{'data': {'width': 640,
#      'cropAvailable': True,
#      'hash': 'listings/270378/06/66/KNMAT2MVXJP606606/D4V2GDXVGEHWCVAQMJ7ZFJGQUU',
#      'height': 480}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': None,
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Dealer Price',
#    'show_discount_post_lead': False,
#    'description': 'no_discounts',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': None},
#   'pricing': {'list_price': 21303,
#    'member_discount': None,
#    'member_price': 21303,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 21303,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 34,
#    'market_difference': 802.4,
#    'market_difference_display': 420,
#    'market_difference_percent': 0.036,
#    'market_difference_percent_display': 2.0,
#    'rating': 'GREAT',
#    'callout': {'label': 'Great Price', 'quality': 'GREAT', 'quality_index': 1},
#    'great': 21884.35,
#    'good': 22768.56,
#    'min': 16579.05,
#    'max': 27631.75,
#    'avg': 22105.4,
#    'exceptional': 21000.13},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': 'KNMAT2MVXJP606606'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'sedan',
#    'body_style': 'Sedan',
#    'drive_train': 'AWD',
#    'engine': '2.0L Inline-4 Gas Turbocharged',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 7341,
#    'model_slug': 'e-class',
#    'model': 'E-Class',
#    'mpg_city': 21,
#    'mpg_combined': 24,
#    'mpg_highway': 29,
#    'style_id': 59447,
#    'style_slug': 'e-300-4matic-sedan',
#    'style': 'E 300 4MATIC Sedan',
#    'transmission': 'Automatic',
#    'trim_slug': 'e-300',
#    'trim': 'E 300 4MATIC Sedan',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 395560,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'Gray',
#    'exterior_color_rgb': '363938',
#    'exterior_color': 'Selenite Grey Metallic',
#    'exterior_color_id': 892378,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': '1B1C20',
#    'interior_color_id': 906671,
#    'list_price': 39901.0,
#    'member_discount': 500.0,
#    'mileage': 38458,
#    'new_or_used': 'USED',
#    'stock_number': '706108',
#    'vin': 'WDDZF4KB0JA346305',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 24,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1627502897134,
#     'isFrameDamaged': False,
#     'ownerCount': 2,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 1,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDDZF4KB0JA346305',
#     'reportPullDateString': '2021-07-28T20:08:17.134+00:00'},
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDDZF4KB0JA346305',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/2441/05/63/WDDZF4KB0JA346305/GP6QVQ2X7YJZVBCA2I4I5XF6BY-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/2441/05/63/WDDZF4KB0JA346305/GP6QVQ2X7YJZVBCA2I4I5XF6BY-318.jpg']},
#   'dealership': {'id': 2441,
#    'name': 'Mercedes-Benz Manhattan',
#    'links': {'website_link': 'http://www.mb-manhattan.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '770 11th Avenue',
#     'address2': None,
#     'postal_code': '10019',
#     'lat': 40.76813,
#     'lng': -73.99287,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 1.26},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-07-28T18:40:00.000+00:00',
#   'images': [{'data': {'width': 640,
#      'cropAvailable': True,
#      'hash': 'listings/2441/05/63/WDDZF4KB0JA346305/GP6QVQ2X7YJZVBCA2I4I5XF6BY',
#      'height': 480}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': 'Upfront Price Available',
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your Upfront Price',
#    'show_discount_post_lead': True,
#    'description': 'restricted_state_and_list_prices',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Upfront Price Available'},
#   'pricing': {'list_price': 39901,
#    'member_discount': None,
#    'member_price': 39901,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 39901,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 32,
#    'market_difference': 1530.72,
#    'market_difference_display': 806,
#    'market_difference_percent': 0.037,
#    'market_difference_percent_display': 2.0,
#    'rating': 'GREAT',
#    'callout': {'label': 'Great Price', 'quality': 'GREAT', 'quality_index': 1},
#    'great': 41017.4,
#    'good': 42674.67,
#    'min': 31073.79,
#    'max': 51789.65,
#    'avg': 41431.72,
#    'exceptional': 39360.13},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': 'WDDZF4KB0JA346305'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'suv',
#    'body_style': 'SUV',
#    'drive_train': 'AWD',
#    'engine': '3.5L V-6 Gas',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 7369,
#    'model_slug': 'gle',
#    'model': 'GLE',
#    'mpg_city': 18,
#    'mpg_combined': 19,
#    'mpg_highway': 22,
#    'style_id': 59472,
#    'style_slug': 'gle-350-4matic-suv',
#    'style': 'GLE 350 4MATIC SUV',
#    'transmission': 'Automatic',
#    'trim_slug': 'gle-350',
#    'trim': 'GLE 350 4MATIC SUV',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 395342,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'White',
#    'exterior_color_rgb': 'E3E4E8',
#    'exterior_color': 'Polar White',
#    'exterior_color_id': 892831,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': '1B1C20',
#    'interior_color_id': 892821,
#    'list_price': 40901.0,
#    'member_discount': 500.0,
#    'mileage': 36882,
#    'new_or_used': 'USED',
#    'stock_number': '706066',
#    'vin': '4JGDA5HBXJB181305',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 26,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1626637011383,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 1,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=4JGDA5HBXJB181305',
#     'reportPullDateString': '2021-07-18T19:36:51.383+00:00'},
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=4JGDA5HBXJB181305',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/2441/05/13/4JGDA5HBXJB181305/75LVV3JIC5XKS27JYSRN6EGUWU-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/2441/05/13/4JGDA5HBXJB181305/75LVV3JIC5XKS27JYSRN6EGUWU-318.jpg']},
#   'dealership': {'id': 2441,
#    'name': 'Mercedes-Benz Manhattan',
#    'links': {'website_link': 'http://www.mb-manhattan.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '770 11th Avenue',
#     'address2': None,
#     'postal_code': '10019',
#     'lat': 40.76813,
#     'lng': -73.99287,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 1.26},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-08-21T18:43:00.000+00:00',
#   'images': [{'data': {'width': 1024,
#      'cropAvailable': True,
#      'hash': 'listings/2441/05/13/4JGDA5HBXJB181305/75LVV3JIC5XKS27JYSRN6EGUWU',
#      'height': 768}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': 'Upfront Price Available',
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your Upfront Price',
#    'show_discount_post_lead': True,
#    'description': 'restricted_state_and_list_prices',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Upfront Price Available'},
#   'pricing': {'list_price': 40901,
#    'member_discount': None,
#    'member_price': 40901,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 40901,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 76,
#    'market_difference': 805.57,
#    'market_difference_display': 286,
#    'market_difference_percent': 0.019,
#    'market_difference_percent_display': 0.7,
#    'rating': 'GREAT',
#    'callout': {'label': 'Great Price', 'quality': 'GREAT', 'quality_index': 1},
#    'great': 41289.5,
#    'good': 42957.76,
#    'min': 31279.92,
#    'max': 52133.21,
#    'avg': 41706.57,
#    'exceptional': 39621.24},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '4JGDA5HBXJB181305'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'suv',
#    'body_style': 'SUV',
#    'drive_train': 'AWD',
#    'engine': '3.5L V-6 Gas',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 7369,
#    'model_slug': 'gle',
#    'model': 'GLE',
#    'mpg_city': 18,
#    'mpg_combined': 19,
#    'mpg_highway': 22,
#    'style_id': 59472,
#    'style_slug': 'gle-350-4matic-suv',
#    'style': 'GLE 350 4MATIC SUV',
#    'transmission': 'Automatic',
#    'trim_slug': 'gle-350',
#    'trim': 'GLE 350 4MATIC SUV',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 395342,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'Black',
#    'exterior_color_rgb': '0A0A0B',
#    'exterior_color': 'Black',
#    'exterior_color_id': 892830,
#    'interior_color': 'Ginger Beige/Black',
#    'interior_color_generic': 'Beige',
#    'interior_color_rgb': 'E8D8BE',
#    'interior_color_id': 892827,
#    'list_price': 39901.0,
#    'member_discount': 500.0,
#    'mileage': 38246,
#    'new_or_used': 'USED',
#    'stock_number': '706017',
#    'vin': '4JGDA5HB5JB123053',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 45,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1624995727059,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 1,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=4JGDA5HB5JB123053',
#     'reportPullDateString': '2021-06-29T19:42:07.059+00:00'},
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=4JGDA5HB5JB123053',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/2441/53/30/4JGDA5HB5JB123053/PTVJHQ5ZXMWRABHGO4B4JJTMUY-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/2441/53/30/4JGDA5HB5JB123053/PTVJHQ5ZXMWRABHGO4B4JJTMUY-318.jpg']},
#   'dealership': {'id': 2441,
#    'name': 'Mercedes-Benz Manhattan',
#    'links': {'website_link': 'http://www.mb-manhattan.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '770 11th Avenue',
#     'address2': None,
#     'postal_code': '10019',
#     'lat': 40.76813,
#     'lng': -73.99287,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 1.26},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-06-29T18:43:00.000+00:00',
#   'images': [{'data': {'width': 640,
#      'cropAvailable': True,
#      'hash': 'listings/2441/53/30/4JGDA5HB5JB123053/PTVJHQ5ZXMWRABHGO4B4JJTMUY',
#      'height': 480}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': 'Upfront Price Available',
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your Upfront Price',
#    'show_discount_post_lead': True,
#    'description': 'restricted_state_and_list_prices',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Upfront Price Available'},
#   'pricing': {'list_price': 39901,
#    'member_discount': None,
#    'member_price': 39901,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 39901,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 81,
#    'market_difference': 708.48,
#    'market_difference_display': 223,
#    'market_difference_percent': 0.017,
#    'market_difference_percent_display': 0.6,
#    'rating': 'GREAT',
#    'callout': {'label': 'Great Price', 'quality': 'GREAT', 'quality_index': 1},
#    'great': 40203.39,
#    'good': 41827.77,
#    'min': 30457.11,
#    'max': 50761.85,
#    'avg': 40609.48,
#    'exceptional': 38579.01},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '4JGDA5HB5JB123053'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'suv',
#    'body_style': 'SUV',
#    'drive_train': 'AWD',
#    'engine': '2.5L Inline-4 Gas',
#    'fuel_type': 'Gas',
#    'make_id': 43,
#    'make_slug': 'nissan',
#    'make': 'Nissan',
#    'model_id': 7495,
#    'model_slug': 'rogue',
#    'model': 'Rogue',
#    'mpg_city': 25,
#    'mpg_combined': 27,
#    'mpg_highway': 32,
#    'style_id': 60664,
#    'style_slug': 'sv-awd',
#    'style': 'SV AWD',
#    'transmission': 'Automatic',
#    'trim_slug': 'sv',
#    'trim': 'SV AWD',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 392017,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'Black',
#    'exterior_color_rgb': '1D2020',
#    'exterior_color': 'Magnetic Black',
#    'exterior_color_id': 914536,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': None,
#    'interior_color_id': None,
#    'list_price': 18495.0,
#    'member_discount': 0.0,
#    'mileage': 29393,
#    'new_or_used': 'USED',
#    'stock_number': '804276',
#    'vin': '5N1AT2MV4JC804276',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
# ...
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 13,
#    'market_difference': 392.9,
#    'market_difference_display': 0,
#    'market_difference_percent': 0.009,
#    'market_difference_percent_display': 0.0,
#    'rating': 'FAIR',
#    'callout': {'label': 'Fair Price', 'quality': 'FAIR', 'quality_index': 2},
#    'great': 44840.97,
#    'good': 46652.72,
#    'min': 33970.43,
#    'max': 56617.38,
#    'avg': 45293.9,
#    'exceptional': 43029.21},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '4JGDA5HB9JB084886'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'suv',
#    'body_style': 'SUV',
#    'drive_train': 'AWD',
#    'engine': '3.5L V-6 Gas',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 7369,
#    'model_slug': 'gle',
#    'model': 'GLE',
#    'mpg_city': 18,
#    'mpg_combined': 19,
#    'mpg_highway': 22,
#    'style_id': 59472,
#    'style_slug': 'gle-350-4matic-suv',
#    'style': 'GLE 350 4MATIC SUV',
#    'transmission': 'Automatic',
#    'trim_slug': 'gle-350',
#    'trim': 'GLE 350 4MATIC SUV',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 395342,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'Gray',
#    'exterior_color_rgb': '363938',
#    'exterior_color': 'Selenite Grey Metallic',
#    'exterior_color_id': 892835,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': '1B1C20',
#    'interior_color_id': 892821,
#    'list_price': 41901.0,
#    'member_discount': 500.0,
#    'mileage': 36892,
#    'new_or_used': 'USED',
#    'stock_number': '706152',
#    'vin': '4JGDA5HB1JB171262',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 16,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 1,
#     'reportPullDate': 1628432245412,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=4JGDA5HB1JB171262',
#     'reportPullDateString': '2021-08-08T14:17:25.412+00:00'},
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=4JGDA5HB1JB171262',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/2441/62/12/4JGDA5HB1JB171262/ULUP3EKXT7EMAOEIK4OQXBQZWM-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/2441/62/12/4JGDA5HB1JB171262/ULUP3EKXT7EMAOEIK4OQXBQZWM-318.jpg']},
#   'dealership': {'id': 2441,
#    'name': 'Mercedes-Benz Manhattan',
#    'links': {'website_link': 'http://www.mb-manhattan.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '770 11th Avenue',
#     'address2': None,
#     'postal_code': '10019',
#     'lat': 40.76813,
#     'lng': -73.99287,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 1.26},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-08-08T12:40:00.000+00:00',
#   'images': [{'data': {'width': 1024,
#      'cropAvailable': True,
#      'hash': 'listings/2441/62/12/4JGDA5HB1JB171262/ULUP3EKXT7EMAOEIK4OQXBQZWM',
#      'height': 768}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': 'Upfront Price Available',
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your Upfront Price',
#    'show_discount_post_lead': True,
#    'description': 'restricted_state_and_list_prices',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Upfront Price Available'},
#   'pricing': {'list_price': 41901,
#    'member_discount': None,
#    'member_price': 41901,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 41901,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 6,
#    'market_difference': 395.36,
#    'market_difference_display': 0,
#    'market_difference_percent': 0.009,
#    'market_difference_percent_display': 0.0,
#    'rating': 'FAIR',
#    'callout': {'label': 'Fair Price', 'quality': 'FAIR', 'quality_index': 2},
#    'great': 41873.4,
#    'good': 43565.25,
#    'min': 31722.27,
#    'max': 52870.46,
#    'avg': 42296.36,
#    'exceptional': 40181.55},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '4JGDA5HB1JB171262'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'sedan',
#    'body_style': 'Sedan',
#    'drive_train': 'FWD',
#    'engine': '3.5L V-6 Gas',
#    'fuel_type': 'Gas',
#    'make_id': 50,
#    'make_slug': 'lexus',
#    'make': 'Lexus',
#    'model_id': 7618,
#    'model_slug': 'es',
#    'model': 'ES',
#    'mpg_city': 21,
#    'mpg_combined': 24,
#    'mpg_highway': 31,
#    'style_id': 45871,
#    'style_slug': 'es-350',
#    'style': 'ES 350',
#    'transmission': 'Automatic',
#    'trim_slug': 'es-350',
#    'trim': 'ES 350',
#    'trim_id': None,
#    'year': 2014,
#    'chrome_trim_id': 364418,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'Gray',
#    'exterior_color_rgb': '66696B',
#    'exterior_color': 'Nebula Gray Pearl',
#    'exterior_color_id': 678380,
#    'interior_color': 'Light Gray',
#    'interior_color_generic': 'Gray',
#    'interior_color_rgb': '838288',
#    'interior_color_id': 678395,
#    'list_price': 17995.0,
#    'member_discount': 225.0,
#    'mileage': 54824,
#    'new_or_used': 'USED',
#    'stock_number': '118090',
#    'vin': 'JTHBK1GG4E2118090',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 28,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1626811236785,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=JTHBK1GG4E2118090',
#     'reportPullDateString': '2021-07-20T20:00:36.785+00:00'},
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'Union City, NJ',
#    'price_dropped': False,
#    'certified_pre_owned': None,
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=JTHBK1GG4E2118090',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/22960/90/80/JTHBK1GG4E2118090/CBJN4YTVSDGCNXNAMTCA7XWTKA-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/22960/90/80/JTHBK1GG4E2118090/CBJN4YTVSDGCNXNAMTCA7XWTKA-318.jpg']},
#   'dealership': {'id': 22960,
#    'name': "2 Manny's Auto Sales",
#    'links': {'website_link': 'http://www.2mannys.com/'},
#    'services': {'remote_purchasing': True,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '1316 Kennedy Blvd',
#     'address2': None,
#     'postal_code': '07087',
#     'lat': 40.76286,
#     'lng': -74.04202,
#     'city': 'Union City',
#     'state': 'NJ',
#     'distance': 2.53},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-07-20T18:40:00.000+00:00',
#   'images': [{'data': {'width': 640,
#      'cropAvailable': True,
#      'hash': 'listings/22960/90/80/JTHBK1GG4E2118090/CBJN4YTVSDGCNXNAMTCA7XWTKA',
#      'height': 480}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': True,
#    'discount_message_pre_lead': 'Discount Available',
#    'show_list_price_post_lead': True,
#    'cert_title': 'Certificate',
#    'member_price_label_post_lead': 'Your Discounted Price',
#    'show_discount_post_lead': True,
#    'description': 'non_restricted_state',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Discount Available'},
#   'pricing': {'list_price': 17995,
#    'member_discount': None,
#    'member_price': 17995,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 17995,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 64,
#    'market_difference': 2494.75,
#    'market_difference_display': 1508,
#    'market_difference_percent': 0.122,
#    'market_difference_percent_display': 8.4,
#    'rating': 'EXCELLENT',
#    'callout': {'label': 'Excellent Price',
#     'quality': 'EXCELLENT',
#     'quality_index': 0},
#    'great': 20284.85,
#    'good': 21104.44,
#    'min': 15367.31,
#    'max': 25612.19,
#    'avg': 20489.75,
#    'exceptional': 19465.26},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': 'JTHBK1GG4E2118090'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'suv',
#    'body_style': 'SUV',
#    'drive_train': 'AWD',
#    'engine': '2.5L Inline-4 Gas',
#    'fuel_type': 'Gas',
#    'make_id': 43,
#    'make_slug': 'nissan',
#    'make': 'Nissan',
#    'model_id': 7495,
#    'model_slug': 'rogue',
#    'model': 'Rogue',
#    'mpg_city': 25,
#    'mpg_combined': 27,
#    'mpg_highway': 32,
#    'style_id': 60664,
#    'style_slug': 'sv-awd',
#    'style': 'SV AWD',
#    'transmission': 'Automatic',
#    'trim_slug': 'sv',
#    'trim': 'SV AWD',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 392017,
#    'carfax_report_available': False,
#    'enable_discount': 'no',
#    'exterior_color_generic': 'Black',
#    'exterior_color_rgb': '1D2020',
#    'exterior_color': 'Magnetic Black',
#    'exterior_color_id': None,
#    'interior_color': 'Charcoal',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': None,
#    'interior_color_id': None,
#    'list_price': 16995.0,
#    'member_discount': 0.0,
#    'mileage': 39600,
#    'new_or_used': 'USED',
#    'stock_number': '2858P',
#    'vin': 'KNMAT2MV6JP501982',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 89,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {'interior': [{'description': 'CHARCOAL, CLOTH SEAT TRIM',
#       'msrp': 0.0,
#       'features': None,
#       'oem_code': 'G'}],
#     'additional equipment': [{'description': 'CHROME REAR BUMPER PROTECTOR',
#       'msrp': 155.0,
#       'features': None,
#       'oem_code': 'BUM'},
#      {'description': 'BLACK SPLASH GUARDS (SET OF 4)',
#       'msrp': 160.0,
#       'features': None,
#       'oem_code': 'SGD'},
#      {'description': 'FLOOR MATS & 2-PC CARGO AREA PROTECTOR',
#       'msrp': 275.0,
#       'features': ['2-pc front and 2-pc 2nd row floor mats', 'First Aid Kit'],
#       'oem_code': 'FL2'}]},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1628451726427,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=KNMAT2MV6JP501982',
#     'reportPullDateString': '2021-08-08T19:42:06.427+00:00'},
#    'multilocation': False,
#    'equipment_rating': 'basicEquipped',
#    'location': 'Hackensack, NJ',
#    'price_dropped': True,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=KNMAT2MV6JP501982',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/151048/82/19/KNMAT2MV6JP501982/KUCGYRFVKV2ZJRFMQZKK67V4LM-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/151048/82/19/KNMAT2MV6JP501982/KUCGYRFVKV2ZJRFMQZKK67V4LM-318.jpg']},
#   'dealership': {'id': 151048,
#    'name': 'Riverside Nissan (NJ)',
#    'links': {'website_link': 'https://www.riversidenissanauto.com/index.cfm'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '400 River Street',
#     'address2': None,
#     'postal_code': '07601',
#     'lat': 40.891,
#     'lng': -74.0384,
#     'city': 'Hackensack',
#     'state': 'NJ',
#     'distance': 9.97},
#    'parent_id': 7840},
#   'payments': {'lease': None,
#    'loan': {'total_monthly_payment': 277.8,
#     'monthly_payment': 258.05,
#     'monthly_tax': 19.75,
#     'total_due_at_signing': 1699.5,
#     'due_at_signing': 1699.5,
#     'taxes_due_at_signing': 0.0,
#     'term': 60,
#     'disclaimer': '$1,700 down payment. 60 monthly payments of $17.52 per $1000 financed at 1.99% APR.'}},
#   'listed_at': '2021-05-25T18:42:00.000+00:00',
#   'images': [{'data': {'width': 1024,
#      'cropAvailable': True,
#      'hash': 'listings/151048/82/19/KNMAT2MV6JP501982/KUCGYRFVKV2ZJRFMQZKK67V4LM',
#      'height': 768}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': None,
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Dealer Price',
#    'show_discount_post_lead': False,
#    'description': 'no_discounts',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': None},
#   'pricing': {'list_price': 16995,
#    'member_discount': None,
#    'member_price': 16995,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 16995,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 80,
#    'market_difference': 1673.45,
#    'market_difference_display': 1020,
#    'market_difference_percent': 0.09,
#    'market_difference_percent_display': 6.0,
#    'rating': 'EXCELLENT',
#    'callout': {'label': 'Excellent Price',
#     'quality': 'EXCELLENT',
#     'quality_index': 0},
#    'great': 18481.76,
#    'good': 19228.5,
#    'min': 14001.33,
#    'max': 23335.56,
#    'avg': 18668.45,
#    'exceptional': 17735.02},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': 'KNMAT2MV6JP501982'},
#   'prospected': False,
#   'prospected_at': None}]

# %%
len(results_json)

#this shows we have made the right selection
# Out:
# 30

# %%
# now we need to grab the information we need for one of the books
results_json[0]
# Out:
# {'vehicle': {'body_style_slug': 'sedan',
#   'body_style': 'Sedan',
#   'drive_train': 'AWD',
#   'engine': '2.0L Inline-4 Gas Turbocharged',
#   'fuel_type': 'Gas',
#   'make_id': 4,
#   'make_slug': 'mercedes-benz',
#   'make': 'Mercedes-Benz',
#   'model_id': 7318,
#   'model_slug': 'c-class',
#   'model': 'C-Class',
#   'mpg_city': 23,
#   'mpg_combined': 26,
#   'mpg_highway': 32,
#   'style_id': 59105,
#   'style_slug': 'c-300-4matic-sedan',
#   'style': 'C 300 4MATIC Sedan',
#   'transmission': 'Automatic',
#   'trim_slug': 'c-300',
#   'trim': 'C 300 4MATIC Sedan',
#   'trim_id': None,
#   'year': 2018,
#   'chrome_trim_id': 395165,
#   'carfax_report_available': False,
#   'enable_discount': 'yes_all_tc',
#   'exterior_color_generic': 'White',
#   'exterior_color_rgb': 'E3E4E8',
#   'exterior_color': 'Polar White',
#   'exterior_color_id': 887864,
#   'interior_color': 'Black',
#   'interior_color_generic': 'Black',
#   'interior_color_rgb': '1B1C20',
#   'interior_color_id': 887849,
#   'list_price': 31901.0,
#   'member_discount': 500.0,
#   'mileage': 19457,
#   'new_or_used': 'USED',
#   'stock_number': '706156',
#   'vin': '55SWF4KB1JU267888',
#   'truecar_make_id': None,
#   'truecar_model_id': None,
#   'doors': None,
#   'newly_listed': None,
#   'days_in_inventory': 15,
#   'make_logos': None,
#   'provider_name': None,
#   'request_price': None,
#   'manufacturer_options': [],
#   'bed_length': None,
#   'cab_type': None,
#   'roof_height': None,
#   'options': {},
#   'condition_history': {'isRentalCar': False,
#    'recallCount': 0,
#    'reportPullDate': 1628432246024,
#    'isFrameDamaged': False,
#    'ownerCount': 1,
#    'titleInfo': {'isSalvage': False,
#     'isCleanTitle': True,
#     'isLemon': False,
#     'isTheftRecovered': False,
#     'isFrameDamaged': False},
#    'isReportFree': False,
#    'maintenanceCount': 0,
#    'accidentCount': 0,
#    'isFleetCar': False,
#    'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB1JU267888',
#    'reportPullDateString': '2021-08-08T14:17:26.024+00:00'},
#   'multilocation': False,
#   'equipment_rating': 'standard',
#   'location': 'New York, NY',
#   'price_dropped': False,
#   'certified_pre_owned': 'oem-certified',
#   'sponsored': None,
#   'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB1JU267888',
#   'frame_damaged': False,
#   'image': 'https://listings-prod.tcimg.net/listings/2441/88/78/55SWF4KB1JU267888/KCEQX3OXGH6I2AOFTOH2EUG7FM-318.jpg',
#   'images': ['https://listings-prod.tcimg.net/listings/2441/88/78/55SWF4KB1JU267888/KCEQX3OXGH6I2AOFTOH2EUG7FM-318.jpg']},
#  'dealership': {'id': 2441,
#   'name': 'Mercedes-Benz Manhattan',
#   'links': {'website_link': 'http://www.mb-manhattan.com/'},
#   'services': {'remote_purchasing': False,
#    'nationwide_delivery_provided': False},
#   'location': {'address1': '770 11th Avenue',
#    'address2': None,
#    'postal_code': '10019',
#    'lat': 40.76813,
#    'lng': -73.99287,
#    'city': 'New York',
#    'state': 'NY',
#    'distance': 1.26},
#   'parent_id': None},
#  'payments': {'lease': None, 'loan': None},
#  'listed_at': '2021-08-08T12:40:00.000+00:00',
#  'images': [{'data': {'width': 1024,
#     'cropAvailable': True,
#     'hash': 'listings/2441/88/78/55SWF4KB1JU267888/KCEQX3OXGH6I2AOFTOH2EUG7FM',
#     'height': 768}}],
#  'pricing_flags': {'show_list_price_label_pre_lead': False,
#   'discount_message_pre_lead': 'Upfront Price Available',
#   'show_list_price_post_lead': False,
#   'cert_title': 'Offer',
#   'member_price_label_post_lead': 'Your Upfront Price',
#   'show_discount_post_lead': True,
#   'description': 'restricted_state_and_list_prices',
#   'show_discount_pre_lead': False,
#   'discount_label_pre_lead': 'Upfront Price Available'},
#  'pricing': {'list_price': 31901,
#   'member_discount': None,
#   'member_price': 31901,
#   'total_fees': 0,
#   'other_fees_total': 0,
#   'dealer_installed_options_total': 0,
#   'total_fees_and_accessories': 0,
#   'total_price': 31901,
#   'transparency_pledge': None,
#   'list_price_includes_doc_fee': None,
#   'dealer_installed_options': [],
#   'savings_total': None,
#   'savings_total_percentage': None,
#   'other_fees': [],
#   'documentation_fee': None,
#   'tax_rate': None,
#   'price_history': None,
#   'tax_amount': None,
#   'total_taxed_price': None},
#  'price_curve': {'recent_offer_averages': None,
#   'curve_distance': 89,
#   'market_difference': 2428.54,
#   'market_difference_display': 1453,
#   'market_difference_percent': 0.071,
#   'market_difference_percent_display': 4.6,
#   'rating': 'EXCELLENT',
#   'callout': {'label': 'Excellent Price',
#    'quality': 'EXCELLENT',
#    'quality_index': 0},
#   'great': 33986.25,
#   'good': 35359.43,
#   'min': 25747.16,
#   'max': 42911.93,
#   'avg': 34329.54,
#   'exceptional': 32613.06},
#  'collapse': {'collapsed': False,
#   'count': 1,
#   'consolidated_dealer': '55SWF4KB1JU267888'},
#  'prospected': False,
#  'prospected_at': None}

# %%
# brand 
results_json[0]['vehicle']['make']
# Out:
# 'Mercedes-Benz'

# %%
# model 
results_json[0]['vehicle']['model']
# Out:
# 'C-Class'

# %%
# mileage
results_json[0]['vehicle']['mileage']
# Out:
# 19457

# %%
# year
results_json[0]['vehicle']['year']
# Out:
# 2018

# %%
# price
results_json[0]['pricing']['list_price']
# Out:
# 31901

# %% [markdown]
# ### putting it all together and get the information automatically and store in dataframe

# %%
brand_ny = []
model_ny = []
mileage_ny = []
year_ny = []
price_ny = []

for result in results_json:
    
    # brand
    brand_ny.append(result['vehicle']['make'])
    
    # model
    model_ny.append(result['vehicle']['model'])
    
    # mileage
    mileage_ny.append(result['vehicle']['mileage'])
    
    # year
    year_ny.append(result['vehicle']['year'])
    
    # price
    price_ny.append(result['pricing']['list_price'])

# %%
df_ny_single = pd.DataFrame({'Brand': brand_ny, 
                             'Model': model_ny, 
                             'Mileage': mileage_ny, 
                             'Year': year_ny,
                             'Price':price_ny})

# %%
df_ny_single
# Out:
#             Brand           Model  Mileage  Year  Price
# 0   Mercedes-Benz         C-Class    19457  2018  31901
# 1            Jeep  Grand Cherokee    26553  2018  30162
# 2   Mercedes-Benz             GLE    29557  2018  39901
# 3   Mercedes-Benz         C-Class    17880  2018  32901
# 4   Mercedes-Benz         C-Class    26317  2018  31901
# 5          Nissan           Rogue    24474  2018  21303
# 6   Mercedes-Benz         E-Class    38458  2018  39901
# 7   Mercedes-Benz             GLE    36882  2018  40901
# 8   Mercedes-Benz             GLE    38246  2018  39901
# 9          Nissan           Rogue    29393  2018  18495
# 10         Toyota            RAV4    43028  2017  19001
# 11  Mercedes-Benz             GLE    44508  2018  38901
# 12          Lexus              ES    29726  2018  28124
# 13         Nissan           Rogue    44943  2018  21256
# 14  Mercedes-Benz             GLE    20443  2018  39995
# 15          Lexus              ES    13357  2018  28710
# 16          Lexus              ES    42230  2018  25904
# 17          Lexus              ES    29288  2018  28841
# 18          Lexus              RX    23286  2017  33749
# 19  Mercedes-Benz             GLE    27661  2018  42901
# 20  Mercedes-Benz             CLA    38934  2018  27901
# 21  Mercedes-Benz             GLE    14719  2018  43901
# 22  Mercedes-Benz             GLC    30131  2019  35901
# 23         Nissan           Rogue    10314  2018  20998
# 24  Mercedes-Benz             GLC     8638  2021  49670
# 25          Lexus              NX    44926  2017  25198
# 26  Mercedes-Benz             GLE    15105  2018  44901
# 27  Mercedes-Benz             GLE    36892  2018  41901
# 28          Lexus              ES    54824  2014  17995
# 29         Nissan           Rogue    39600  2018  16995

# %% [markdown]
# #### Scraping Multiple Pages (here: ~5000results)

# %%
brand_ny = []
model_ny = []
mileage_ny = []
year_ny = []
price_ny = []

for i in range(1,170):
    # checked the website and saw that page 170 gives us around 5000 records

    headers = {
        'authority': 'www.truecar.com',
        'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^92^\\^, ^\\^',
        'accept': 'application/json, text/plain, */*',
        'x-xsrf-token': 'Ur/kxt0PrKLpIlS3QELPXZBZHMSME0gTzs47TPfIUiC1LJqIt9HlLYrLTMgwB5qE6zC2M5Psn5Er+4Qm82MgEA==',
        'sec-ch-ua-mobile': '?0',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'sec-fetch-dest': 'empty',
        'referer': 'https://www.truecar.com/used-cars-for-sale/listings/location-new-york-ny/',
        'accept-language': 'en-US,en;q=0.9,de-DE;q=0.8,de;q=0.7',
        'cookie': 'tc_v=732d8f6c-016d-4e04-99ea-962821b285bd; u=rBEABWDn9kVuLQARuYhKAg==; user_zip_code_san-francisco-ca=94102; user_zip_code_new-york-ny=10001; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; _abp_auth_s=aLdzR1stp7FxiV6Cbnggg8fmtny6X9FAap2fnCqWeXg; referrer=ZTC0000000; g_state=^{^\\^i_p^\\^:1628151776913,^\\^i_l^\\^:2^}; capselaPreferredPostalCode=10001; XSRF-TOKEN=Ur^%^2Fkxt0PrKLpIlS3QELPXZBZHMSME0gTzs47TPfIUiC1LJqIt9HlLYrLTMgwB5qE6zC2M5Psn5Er^%^2B4Qm82MgEA^%^3D^%^3D; _abp_backend_session=cnN3bFdMQjJQYTlwRFFvS3oybm1oWTl0SVc3NVNGRng5Y01GWHlxa3BybWFJRXM1UkFueTFRWUhMYUtSVW1YZWxNaUFIZ2ZjS2FUQ2pVeURRNG5PeEh6VlRFQjZnRmFLN01PWHZFdjBQTis5UG9VRGFtWko4MFZNY2ZUUGRmS1pkSFdmcnB4TVkwMnJGREZBblZla1RRPT0tLW5BQjFPdHVvTk1VbHJZL3lwQ2MrTUE9PQ^%^3D^%^3D--a4caf99167368bcbbcd454b4ffe52eb35169abe0; _dd_s=rum=0&expire=1628067151364',
        'if-none-match': 'W/^\\^ad5f12263df3f1f7dad67afa854d2880^\\^',
    }

    params = (
        ('city', 'new-york'),
        ('collapse', 'true'),
        ('fallback', 'true'),
        ('include_incentives', 'true'),
        ('include_targeted_incentives', 'true'),
        ('new_or_used', 'u'),
        ('page', str(i)),
        ('per_page', '30'),
        ('postal_code', '10001'),
        ('search_event', 'true'),
        ('sort^/[^/]', 'best_match'),
        ('sponsored', 'true'),
        ('state', 'ny'),
    )

    # response
    response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings', headers=headers, params=params)

 
    # json object
    json_response = response.json()
    
    # result items (30 items per page)
    results_json = json_response['listings']
    
    for result in results_json:
    
        # brand
        brand_ny.append(result['vehicle']['make'])

        # model
        model_ny.append(result['vehicle']['model'])

        # mileage
        mileage_ny.append(result['vehicle']['mileage'])

        # year
        year_ny.append(result['vehicle']['year'])

        # price
        price_ny.append(result['pricing']['list_price'])

# %%
df_ny_multiple = pd.DataFrame({'Brand': brand_ny, 'Model': model_ny, 'Mileage': mileage_ny, 'Year': year_ny,
                             'Price':price_ny})

# %%
df_ny_multiple

# %%
df_ny_single.to_excel('output_5k.xlsx', index=False)

# %% [markdown]
# # Part 2 - Truecar.com - San Francisco

# %%
brand_sf = []
model_sf = []
mileage_sf = []
year_sf = []
price_sf = []

for i in range(1,170):
    headers = {
        'authority': 'www.truecar.com',
        'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^92^\\^, ^\\^',
        'accept': 'application/json, text/plain, */*',
        'x-xsrf-token': 'sRHovNRE9jEGmReSnaj0SFGY/L5+yUbMUmoVcX3SrQpWgpbyvpq/vmVwD+3t7aGRKvFWSWE2kU63X6obeXnfOg==',
        'sec-ch-ua-mobile': '?0',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'sec-fetch-dest': 'empty',
        'referer': 'https://www.truecar.com/used-cars-for-sale/listings/location-san-francisco-ca/',
        'accept-language': 'en-US,en;q=0.9,de-DE;q=0.8,de;q=0.7',
        'cookie': 'tc_v=732d8f6c-016d-4e04-99ea-962821b285bd; u=rBEABWDn9kVuLQARuYhKAg==; user_zip_code_san-francisco-ca=94102; user_zip_code_new-york-ny=10001; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; _abp_auth_s=aLdzR1stp7FxiV6Cbnggg8fmtny6X9FAap2fnCqWeXg; referrer=ZTC0000000; g_state=^{^\\^i_p^\\^:1628151776913,^\\^i_l^\\^:2^}; capselaPreferredPostalCode=94102; XSRF-TOKEN=sRHovNRE9jEGmReSnaj0SFGY^%^2FL5^%^2ByUbMUmoVcX3SrQpWgpbyvpq^%^2FvmVwD^%^2B3t7aGRKvFWSWE2kU63X6obeXnfOg^%^3D^%^3D; _abp_backend_session=a3VMTkJGelNWbmptb3Q4aHlObjNIT1VXNFBZNXREeEg0SHo4MEZGdTNoalFRSzV2VldsaStYa3J6UDZSdGJvZDJsRUtXUkJVZ0ZycXhrbU5PZ0gxZms3RGFtRFJVbXZTeTFzeGI3WGo2VGVxUmptdm1OYVdmZGVrWlFvMDIxQVdLZ1BnM1A2SGZBa1pKbXhERlZOVzlRPT0tLW9ONTI2Y0xLM0lLY1g1NE5qSEpaSVE9PQ^%^3D^%^3D--4c4bf94f0b241212f5e3b798c48f4a5f0e366f7f; _dd_s=rum=0&expire=1628089775124',
        'if-none-match': 'W/^\\^a5ee0fa2b55644cda4fcbfe817357d97^\\^',
    }

    params = (
        ('city', 'san-francisco'),
        ('collapse', 'true'),
        ('fallback', 'true'),
        ('include_incentives', 'true'),
        ('include_targeted_incentives', 'true'),
        ('new_or_used', 'u'),
        ('page', str(i)),
        ('per_page', '30'),
        ('postal_code', '94102'),
        ('search_event', 'true'),
        ('sort^/[^/]', 'best_match'),
        ('sponsored', 'true'),
        ('state', 'ca'),
    )

    # response
    response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings', headers=headers, params=params)

    # json object
    json_response = response.json()
    
    # result items (30 items per page)
    results_json = json_response['listings']
    
    for result in results_json:
    
        # brand
        brand_sf.append(result['vehicle']['make'])

        # model
        model_sf.append(result['vehicle']['model'])

        # mileage
        mileage_sf.append(result['vehicle']['mileage'])

        # year
        year_sf.append(result['vehicle']['year'])

        # price
        price_sf.append(result['pricing']['list_price'])

# %%
df_sf_multiple = pd.DataFrame({'Brand': brand_sf, 'Model': model_sf, 'Mileage': mileage_sf, 'Year': year_sf,
                             'Price':price_sf})

# %%
df_sf_multiple

# %% [markdown]
# # Part 3 - Combine Data & Connect to Database - PostgreSQL

# %%
# merge dataframes
merged_dataframes = pd.concat([df_ny_multiple, df_sf_multiple], ignore_index=True)

# %%
merged_dataframes

# %%
merged_dataframes['Price'] = merged_dataframes['Price'].astype('Int64')

# %%
# output updated dataframe
merged_dataframes

# %% [markdown]
# #### Excel File

# %%
merged_dataframes.to_excel('merged_dataframes.xlsx', index=False)

# %% [markdown]
# #### Connect to PostgreSQL

# %%
# create sqlalchemy engine
engine = create_engine(#'postgres://postgres:password@localhost:portnumber')
merged_dataframes.to_sql('merged_dataframes', engine)
